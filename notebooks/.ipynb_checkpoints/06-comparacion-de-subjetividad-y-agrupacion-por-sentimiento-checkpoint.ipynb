# %% [markdown]
# # Comparación de Clasificación de Subjetividad y Agrupación por Sentimiento
#
# Este notebook realiza una comparación exhaustiva entre los diferentes métodos de clasificación de subjetividad implementados:
#
# ## Métodos a Comparar
# 1. **HuggingFace (SubjetividadConHF)**: Clasificación binaria (Subjetivo/Objetivo)
# 2. **Análisis por Frases (SubjetividadConFrases)**: Clasificación ternaria (Subjetivo/Objetivo/Mixta)
# 3. **LLM (SubjetividadConLLM)**: Clasificación ternaria (Subjetivo/Objetivo/Mixta)
#
# **Nota**: El método LLM originalmente usa terminología femenina (Subjetiva/Objetiva), pero se normaliza automáticamente a terminología masculina (Subjetivo/Objetivo) para permitir comparaciones consistentes.
#
# ## Análisis a Realizar
# - Comparación HF vs Frases: transiciones y cambios en clasificación
# - Comparación Frases vs LLM: análisis de coincidencias entre métodos ternarios
# - Análisis de discrepancias: casos donde los métodos difieren
# - Agrupación final por sentimiento para el método seleccionado

# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path

sys.path.append('../scripts')

from subjetividad import (
    cargar_datos_para_comparacion,
    realizar_comparacion_completa,
    generar_visualizaciones_completas,
    ComparadorMetodosSubjetividad,
    analizar_discrepancias_completas
)

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')
sns.set_palette("husl")
# %matplotlib inline

print("✅ Librerías y módulos importados correctamente")
# Out:
# ✅ Librerías y módulos importados correctamente

# %% [markdown]
# ## 1. Carga de Datos
#
# Cargamos el dataset con los análisis de subjetividad ya realizados por los diferentes métodos.

# %%
df = cargar_datos_para_comparacion('../data/processed/dataset_opiniones_analisis.csv')
# Out:
# ✅ Dataset cargado: 2464 opiniones
# 📋 Columnas de subjetividad disponibles: ['SubjetividadConHF', 'SubjetividadConFrases', 'SubjetividadConLLM']
#
# 🔍 Valores únicos detectados:
#    • SubjetividadConHF: ['Subjetivo', 'Objetivo']
#    • SubjetividadConFrases: ['Subjetivo', 'Mixta', 'Objetivo']
#    • SubjetividadConLLM: ['Subjetiva', 'Mixta', 'Objetiva']
#
# ✅ Normalización aplicada a SubjetividadConLLM:
#    • 'Subjetiva' → 'Subjetivo'
#    • 'Objetiva' → 'Objetivo'
#    • SubjetividadConLLM valores normalizados: ['Subjetivo', 'Mixta', 'Objetivo']

# %% [markdown]
# ## 2. Comparación HuggingFace vs Análisis por Frases
#
# Análisis de transiciones entre la clasificación binaria de HuggingFace y la clasificación ternaria del análisis por frases.

# %%
comparador = ComparadorMetodosSubjetividad(df)
resultados_hf_frases = comparador.comparar_hf_vs_frases()
comparador.mostrar_comparacion_hf_frases(resultados_hf_frases)
# Out:
# 🔄 COMPARACIÓN: HuggingFace vs Análisis por Frases
# ...
#
# 📊 Tabla de Contingencia:
# SubjetividadConFrases  Mixta  Objetivo  Subjetivo   All
# SubjetividadConHF
# Objetivo                 142        50          0   192
# Subjetivo               1432        13        827  2272
# All                     1574        63        827  2464
#
# 📈 Transiciones desde Subjetivo (HF): 2272 opiniones
#    • Permanece Subjetivo: 827 (36.4%)
#    • Se vuelve Mixta: 1432 (63.0%)
#    • Se vuelve Objetivo: 13 (0.6%)
#
# 📉 Transiciones desde Objetivo (HF): 192 opiniones
#    • Permanece Objetivo: 50 (26.0%)
#    • Se vuelve Mixta: 142 (74.0%)
#    • Se vuelve Subjetivo: 0 (0.0%)

# %%
comparador.visualizar_comparacion_hf_frases(resultados_hf_frases)

# %% [markdown]
# ## 3. Comparación Análisis por Frases vs LLM (Solo Coincidencias)
#
# Análisis enfocado únicamente en las opiniones donde ambos métodos coinciden en la clasificación.

# %%
resultados_frases_llm = comparador.comparar_frases_vs_llm_coincidencias()
comparador.mostrar_comparacion_frases_llm(resultados_frases_llm)
# Out:
# 🔄 COMPARACIÓN: Análisis por Frases vs LLM (Solo Coincidencias)
# ...
#
# 📊 Tabla de Contingencia Completa:
# SubjetividadConLLM     Mixta   All
# SubjetividadConFrases
# Mixta                   1342  1342
# Objetivo                  48    48
# Subjetivo                423   423
# All                     1813  1813
#
# 🎯 Resumen de Coincidencias:
#    • Total de opiniones: 2464
#    • Coincidencias totales: 1342
#    • Porcentaje de coincidencia: 54.5%
#
# 📈 Coincidencias por Tipo:
#    • Mixta: 1342 opiniones (85.3% de coincidencia)
#
# 📋 Distribución en Análisis por Frases:
#    • Mixta: 1574 (63.9%)
#    • Subjetivo: 827 (33.6%)
#    • Objetivo: 63 (2.6%)
#
# 📋 Distribución en LLM:
#    • Mixta: 1813 (73.6%)

# %%
comparador.visualizar_comparacion_frases_llm(resultados_frases_llm)

# %% [markdown]
# ## 4. Resumen Comparativo de Métodos
#
# Análisis de distribuciones y características de cada método para facilitar la selección del mejor enfoque.

# %%
print("📊 RESUMEN DE DISTRIBUCIONES POR MÉTODO")
print("=" * 60)

metodos = ['SubjetividadConHF', 'SubjetividadConFrases', 'SubjetividadConLLM']
for metodo in metodos:
    if metodo in df.columns:
        print(f"\n🔹 {metodo}:")
        distribucion = df[metodo].value_counts()
        total = len(df)
        for categoria, cantidad in distribucion.items():
            porcentaje = (cantidad / total * 100)
            print(f"   • {categoria}: {cantidad} ({porcentaje:.1f}%)")

print(f"\n📋 Total de opiniones analizadas: {len(df)}")
# Out:
# 📊 RESUMEN DE DISTRIBUCIONES POR MÉTODO
# ...
#
# 🔹 SubjetividadConHF:
#    • Subjetivo: 2272 (92.2%)
#    • Objetivo: 192 (7.8%)
#
# 🔹 SubjetividadConFrases:
#    • Mixta: 1574 (63.9%)
#    • Subjetivo: 827 (33.6%)
#    • Objetivo: 63 (2.6%)
#
# 🔹 SubjetividadConLLM:
#    • Mixta: 1813 (73.6%)
#    • Subjetivo: 630 (25.6%)
#    • Objetivo: 21 (0.9%)
#
# 📋 Total de opiniones analizadas: 2464

# %% [markdown]
# ## 4.1. Análisis Detallado de Discrepancias
#
# Examen de casos específicos donde los métodos difieren en sus clasificaciones para entender mejor las fortalezas y debilidades de cada enfoque.

# %%
resultados_discrepancias = analizar_discrepancias_completas(df, n_ejemplos=3)
# Out:
# ...
# 🔍 ANÁLISIS DE DISCREPANCIAS ENTRE MÉTODOS
# ...
# 📊 Métodos comparados: SubjetividadConHF vs SubjetividadConFrases
# 📈 Total de discrepancias: 1587
# 📋 Total de opiniones: 2464
# 📊 Porcentaje de discrepancias: 64.4%
#
# 🔄 TIPOS DE DISCREPANCIAS:
# --------------------------------------------------
#
# 🔸 Subjetivo → Mixta
#    Cantidad: 1432 (90.2% de las discrepancias)
#
# 📝 Ejemplos:
#       1. "La playa con el mejor azul. Es la playa con el azul más intenso de cancun vale la pena ir aunque el oleaje es muy fuerte,  es una de las últimas playas de la zona hotelera y no hay negocios de comida cerca por lo que te recomiendo llevar tus alimentos. A un lado se encuentra el letrero de cancun donde podrás tomarte fotitos de recuerdo."
#          SubjetividadConHF: Subjetivo | SubjetividadConFrases: Mixta
#
# ...

# %% [markdown]
# ## 5. Análisis Cruzado: Subjetividad vs Sentimientos
#
# Análisis de la distribución de sentimientos para cada categoría de subjetividad en los métodos ternarios (SubjetividadConFrases y SubjetividadConLLM).
#
# **Configurable**: Se puede seleccionar entre SentimientoPorCardiff, SentimientoPorHF o SentimientoPorCalificacion.

# %%
from subjetividad import (
    AnalizadorCruzadoSentimientos,
    realizar_analisis_cruzado_completo,
    generar_visualizaciones_cruzadas
)

# %% [markdown]
# ### Configuración del Análisis
#
# Selección del método de sentimientos a utilizar en el análisis cruzado.

# %%
# Configuración: Cambiar aquí para usar diferente método de sentimientos
COLUMNA_SENTIMIENTO = 'SentimientoPorHF'  # Opciones: 'SentimientoPorCardiff', 'SentimientoPorHF', 'SentimientoPorCalificacion'

print(f"🎯 Método de sentimientos seleccionado: {COLUMNA_SENTIMIENTO}")
print(f"📊 Métodos de subjetividad a analizar: SubjetividadConFrases, SubjetividadConLLM")
# Out:
# 🎯 Método de sentimientos seleccionado: SentimientoPorHF
# 📊 Métodos de subjetividad a analizar: SubjetividadConFrases, SubjetividadConLLM

# %% [markdown]
# ### 5.1. Análisis SubjetividadConFrases vs Sentimientos
#
# Análisis de cómo se distribuyen los sentimientos en cada categoría de subjetividad para el método de análisis por frases.

# %%
analizador_cruzado = AnalizadorCruzadoSentimientos(df, COLUMNA_SENTIMIENTO)
resultados_frases = analizador_cruzado.analizar_metodo_subjetividad('SubjetividadConFrases')
analizador_cruzado.mostrar_resumen(resultados_frases)
# Out:
# 📊 ANÁLISIS CRUZADO: SubjetividadConFrases vs SentimientoPorHF
# ...
#
# 🔹 Subjetivo:
#    Total: 827 opiniones (33.6%)
#    Distribución por sentimiento:
#      • Positivo: 745 (90.1%)
#      • Negativo: 53 (6.4%)
#      • Neutro: 29 (3.5%)
#
# 🔹 Mixta:
#    Total: 1574 opiniones (63.9%)
#    Distribución por sentimiento:
#      • Positivo: 1273 (80.9%)
#      • Negativo: 190 (12.1%)
#      • Neutro: 111 (7.1%)
#
# 🔹 Objetivo:
#    Total: 63 opiniones (2.6%)
#    Distribución por sentimiento:
#      • Positivo: 47 (74.6%)
#      • Neutro: 8 (12.7%)
#      • Negativo: 8 (12.7%)

# %%
analizador_cruzado.visualizar_analisis(resultados_frases)

# %% [markdown]
# #### Ejemplos por Categoría - SubjetividadConFrases
#
# Ejemplos específicos de opiniones para cada combinación de subjetividad y sentimiento.

# %%
ejemplos_frases = analizador_cruzado.obtener_ejemplos_por_categoria('SubjetividadConFrases')
analizador_cruzado.mostrar_ejemplos(ejemplos_frases, 'SubjetividadConFrases')
# Out:
# 📝 EJEMPLOS POR CATEGORÍA - SubjetividadConFrases vs SentimientoPorHF
# ...
#
# 🏷️  CATEGORÍA: Subjetivo
# --------------------------------------------------
#
#    💭 Positivo:
#
#    📍 Ejemplo 1:
#       🏨 Cdmx - Museo Soumaya
#       📰 Título: La mejor..
#       💬 Review: Altamente recomendado un gran lugar para admirar grandes obras del.mundo, son varios pisos con historia, me gustó volvería a vivir la experiencia
#
#
#    📍 Ejemplo 2:
#       🏨 Cdmx - Museo Nacional De Antropologia
#       📰 Título: Gran museo
#       💬 Review: Me encanta que puedes conocer grandes cosas sobre la historia de las civilizaciones, y es que aquí se pueden aprender grandes cosas sobre la historia mexicana.
#
#
#    💭 Negativo:
#
#    📍 Ejemplo 1:
#       🏨 Cdmx - Acuario Michin Ciudad De Mexico
#       📰 Título: Mi dia en Acuario Michin
# ...

# %% [markdown]
# ### 5.2. Análisis SubjetividadConLLM vs Sentimientos
#
# Análisis de cómo se distribuyen los sentimientos en cada categoría de subjetividad para el método LLM.

# %%
resultados_llm = analizador_cruzado.analizar_metodo_subjetividad('SubjetividadConLLM')
analizador_cruzado.mostrar_resumen(resultados_llm)
# Out:
# 📊 ANÁLISIS CRUZADO: SubjetividadConLLM vs SentimientoPorHF
# ...
#
# 🔹 Subjetivo:
#    Total: 630 opiniones (25.6%)
#    Distribución por sentimiento:
#      • Positivo: 546 (86.7%)
#      • Negativo: 78 (12.4%)
#      • Neutro: 6 (1.0%)
#
# 🔹 Mixta:
#    Total: 1813 opiniones (73.6%)
#    Distribución por sentimiento:
#      • Positivo: 1501 (82.8%)
#      • Negativo: 171 (9.4%)
#      • Neutro: 141 (7.8%)
#
# 🔹 Objetivo:
#    Total: 21 opiniones (0.9%)
#    Distribución por sentimiento:
#      • Positivo: 18 (85.7%)
#      • Negativo: 2 (9.5%)
#      • Neutro: 1 (4.8%)

# %%
analizador_cruzado.visualizar_analisis(resultados_llm)

# %% [markdown]
# #### Ejemplos por Categoría - SubjetividadConLLM
#
# Ejemplos específicos de opiniones para cada combinación de subjetividad y sentimiento según el método LLM.

# %%
ejemplos_llm = analizador_cruzado.obtener_ejemplos_por_categoria('SubjetividadConLLM')
analizador_cruzado.mostrar_ejemplos(ejemplos_llm, 'SubjetividadConLLM')
# Out:
# 📝 EJEMPLOS POR CATEGORÍA - SubjetividadConLLM vs SentimientoPorHF
# ...
#
# 🏷️  CATEGORÍA: Subjetivo
# --------------------------------------------------
#
#    💭 Positivo:
#
#    📍 Ejemplo 1:
#       🏨 Puebla - Fuertes De Loreto
#       📰 Título: Una puerta al pasado
#       💬 Review: Sentir el clima que sintieron y vivieron durante el asedio francés, recorrer los pasillos durante la batalla, dar un paso al pasado, dominar la vista de la ciudad que se yergue majestuosa... Eso se siente en el Fuerte, ven y no te arrepentirás!!!
#
#
#    📍 Ejemplo 2:
#       🏨 Cancun - Avenida Kukulkan
#       📰 Título: Vacation
#       💬 Review: Nice place to have a great walk, dinner and enjoy the great weather of Cancun, Good restaurants and a lot of bars to have great time.
#
#
#    💭 Negativo:
#
#    📍 Ejemplo 1:
#       🏨 Cdmx - Museo Frida Kahlo
#       📰 Título: Tourist Trap. Skip it!
# ...

# %% [markdown]
# ### 5.3. Comparación Visual entre Métodos
#
# Comparación lado a lado de cómo cada método distribuye los sentimientos por categoría de subjetividad.

# %%
resultados_comparacion = {
    'SubjetividadConFrases': resultados_frases,
    'SubjetividadConLLM': resultados_llm
}
analizador_cruzado.visualizar_comparacion_metodos(resultados_comparacion)

# %% [markdown]
# ## 6. Conclusiones del Análisis Cruzado
#
# ### Observaciones Clave:
#
# **Distribución por Sentimientos:**
# - **Positivo**: Análisis de cómo cada método clasifica las opiniones positivas según subjetividad
# - **Neutro**: Evaluación de opiniones neutras y su clasificación de subjetividad
# - **Negativo**: Comportamiento de cada método ante opiniones negativas
#
# **Comparación entre Métodos:**
# - **SubjetividadConFrases**: Ofrece clasificación ternaria con detección de opiniones mixtas
# - **SubjetividadConLLM**: Proporciona análisis más matizado con mayor granularidad
#
# **Patrones Identificados:**
# - Relación entre la intensidad del sentimiento y la subjetividad detectada
# - Diferencias en la clasificación de opiniones mixtas entre métodos
# - Consistencia en la detección de patrones emocionales
#
# Este análisis permite seleccionar el método más adecuado según los objetivos específicos del análisis de opiniones turísticas.
