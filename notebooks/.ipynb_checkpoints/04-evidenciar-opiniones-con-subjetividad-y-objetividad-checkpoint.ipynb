# %% [markdown]
# # Evidenciando Opiniones Mixtas: Análisis de Subjetividad y Objetividad por Frases
#
# ## Hipótesis de Investigación
#
# **Problema identificado**: En el análisis previo de subjetividad, se obtuvo que solo el ~5% de las opiniones fueron clasificadas como objetivas, lo cual es menos de lo esperado considerando que las opiniones objetivas proporcionan información valiosa para los turistólogos.
#
# **Hipótesis**: Las opiniones turísticas son frecuentemente **mixtas**, es decir, contienen tanto frases subjetivas (opiniones, emociones) como frases objetivas (información factual). El modelo de clasificación actual, entrenado en textos puramente objetivos o puramente subjetivos, tiende a clasificar textos mixtos como subjetivos, perdiendo así la información objetiva valiosa.
#
# ## Metodología para Validar la Hipótesis
#
# 1. **Segmentación de opiniones**: Usar un modelo de deep learning (WtP-Split) para dividir cada opinión en frases individuales
# 2. **Clasificación por frase**: Analizar la subjetividad de cada frase por separado
# 3. **Reclasificación de opiniones**: Clasificar cada opinión completa como:
#    - **Subjetiva**: Solo contiene frases subjetivas
#    - **Objetiva**: Solo contiene frases objetivas
#    - **Mixta**: Contiene al menos una frase objetiva Y una frase subjetiva
# 4. **Análisis de resultados**: Determinar qué porcentaje de opiniones son realmente mixtas
#
# ## Objetivo
#
# Demostrar si existe un porcentaje significativo de opiniones mixtas que están siendo mal clasificadas, lo que explicaría la baja proporción de opiniones objetivas en el análisis inicial.

# %%
# Importar módulos necesarios
import sys
import os
from pathlib import Path

sys.path.append('../scripts')

from subjetividad import (
    cargar_dataset_para_subjetividad,
    mostrar_info_dataset,
    verificar_compatibilidad_cuda,
    analizar_opiniones_mixtas,
    visualizar_distribucion_tipos,
    mostrar_resumen_ejecutivo,
    mostrar_conclusiones_hipotesis,
    AnalizadorOpinionesMixtas,
    actualizar_dataset_principal
)

print(f"CUDA disponible: {verificar_compatibilidad_cuda()}")
print("✅ Módulos importados correctamente")

# Demostración de segmentación de frases con ejemplo
from wtpsplit import SaT
import torch

opinion_mixta = """Me encantó este lugar, es increíble y lo recomiendo mucho. 
El museo abre de 9:00 AM a 6:00 PM todos los días. 
La entrada cuesta 150 pesos por persona. 
Excelente atención al cliente, muy amables todos."""

print(f"\n📝 Opinión mixta de ejemplo:")
print(f'"{opinion_mixta}"')

# Configurar segmentador
sat_sm = SaT("sat-3l-sm")
if torch.cuda.is_available():
    sat_sm.half().to("cuda")

# Segmentar la opinión
frases_segmentadas = sat_sm.split(opinion_mixta)

print(f"\n📊 Total de frases detectadas: {len(frases_segmentadas)}")
for i, frase in enumerate(frases_segmentadas, 1):
    frase_limpia = frase.strip()
    if frase_limpia:
        print(f"  {i}. '{frase_limpia}'")
# Out:
# CUDA disponible: True
# ✅ Módulos importados correctamente
#
# 📝 Opinión mixta de ejemplo:
# "Me encantó este lugar, es increíble y lo recomiendo mucho.
# El museo abre de 9:00 AM a 6:00 PM todos los días.
# La entrada cuesta 150 pesos por persona.
# Excelente atención al cliente, muy amables todos."
#
# 📊 Total de frases detectadas: 7
#   1. 'Me encantó este lugar, es increíble y lo recomiendo mucho.'
#   3. 'El museo abre de 9:00 AM a 6:00 PM todos los días.'
#   5. 'La entrada cuesta 150 pesos por persona.'
#   7. 'Excelente atención al cliente, muy amables todos.'

# %%
# Cargar dataset principal con análisis completo
import pandas as pd

# Usar directamente el dataset principal 
ruta_dataset_principal = '../data/processed/dataset_opiniones_analisis.csv'

try:
    df = pd.read_csv(ruta_dataset_principal)
    fuente_datos = f"Dataset principal completo (desde {ruta_dataset_principal})"
    print(f"✅ Dataset cargado exitosamente desde archivo principal")
except FileNotFoundError:
    print(f"❌ Error: No se encontró el archivo {ruta_dataset_principal}")
    print(f"🔄 Verificar que existe el archivo dataset_opiniones_analisis.csv")
    # Fallback al método del módulo
    df, fuente_datos = cargar_dataset_para_subjetividad('../data/processed/')

mostrar_info_dataset(df, fuente_datos)
df.head()
# Out:
# ✅ Dataset cargado exitosamente desde archivo principal
# 📊 Dataset cargado: 2464 filas | Fuente: Dataset principal completo (desde ../data/processed/dataset_opiniones_analisis.csv)
# 📋 Distribución de subjetividad (SubjetividadConHF):
#    • Subjetivo: 2272 (92.2%)
#    • Objetivo: 192 (7.8%)
#                              Titulo  \
# 0                   Noche diferente
# 1                  Fun and exciting
# 2                         Increíble
# 3               Great fun in Cancun
# 4  Xochimilco excelente experiencia
#
#                                               Review  Calificacion  \
# 0  Speechless. I never thought I'd have such a pl...             5
# 1  Transportation was organized.  Reception at th...             5
# 2  Ninguno, me encantó toda la experiencias fue i...             5
# 3  This is a fabulous show, high energy and great...             5
# 4  Joss y Roberto dieron muy buen servicio y ambi...             5
#
# ...

# %%
# Análisis completo de opiniones mixtas usando módulo especializado
MUESTRA_ANALISIS = len(df)  # Usar dataset completo o cambiar por número menor para pruebas

# Aplicar análisis modular
df_analisis = analizar_opiniones_mixtas(
    df.sample(min(MUESTRA_ANALISIS, len(df)), random_state=42) if MUESTRA_ANALISIS < len(df) else df,
    columna_texto='TituloReview',
    mostrar_ejemplos=True,
    n_ejemplos=3
)
# Out:
# Device set to use cuda:0
# 🔄 Procesando lote 1-10 de 2464 opiniones...
# 🔄 Procesando lote 11-20 de 2464 opiniones...
# 🔄 Procesando lote 21-30 de 2464 opiniones...
# 🔄 Procesando lote 31-40 de 2464 opiniones...
# 🔄 Procesando lote 41-50 de 2464 opiniones...
# 🔄 Procesando lote 51-60 de 2464 opiniones...
# 🔄 Procesando lote 61-70 de 2464 opiniones...
# 🔄 Procesando lote 71-80 de 2464 opiniones...
# 🔄 Procesando lote 81-90 de 2464 opiniones...
# 🔄 Procesando lote 91-100 de 2464 opiniones...
# 🔄 Procesando lote 101-110 de 2464 opiniones...
# 🔄 Procesando lote 111-120 de 2464 opiniones...
# 🔄 Procesando lote 121-130 de 2464 opiniones...
# 🔄 Procesando lote 131-140 de 2464 opiniones...
# 🔄 Procesando lote 141-150 de 2464 opiniones...
# 🔄 Procesando lote 151-160 de 2464 opiniones...
# 🔄 Procesando lote 161-170 de 2464 opiniones...
# 🔄 Procesando lote 171-180 de 2464 opiniones...
# 🔄 Procesando lote 181-190 de 2464 opiniones...
# 🔄 Procesando lote 191-200 de 2464 opiniones...
# ...

# %%
# Visualización de distribución de tipos de opiniones
visualizar_distribucion_tipos(df_analisis)

# %%
# Resumen ejecutivo y validación de hipótesis

# Calcular estadísticas y validar hipótesis
analizador = AnalizadorOpinionesMixtas()
estadisticas = analizador.obtener_estadisticas_mixtas(df_analisis)
validacion = analizador.validar_hipotesis(estadisticas)

# Mostrar resultados finales
mostrar_resumen_ejecutivo(estadisticas)
mostrar_conclusiones_hipotesis(validacion, estadisticas)
# Out:
# 🎯 RESUMEN EJECUTIVO - ANÁLISIS DE OPINIONES MIXTAS
# ...
# 📊 RESULTADOS PRINCIPALES:
# • Total opiniones analizadas: 2464
# • Opiniones mixtas identificadas: 1574 (63.9%)
#
# 📋 DISTRIBUCIÓN POR TIPOS:
# • Mixta: 1574 (63.9%)
# • Subjetivo: 827 (33.6%)
# • Objetivo: 63 (2.6%)
#
# 🔍 ANÁLISIS GRANULAR:
# • Total frases analizadas: 11636
# • Promedio frases por opinión: 4.7
# • Distribución: 64.1% subjetivas, 35.9% objetivas
#
# 💡 IMPLICACIONES PARA TURISTOLOGÍA:
# • Las opiniones mixtas representan una fuente significativa de información
# • Combinan percepciones emocionales con datos prácticos útiles
# • Metodología validada para extracción de contenido híbrido
#
# ✅ Metodología aplicada exitosamente: Segmentación + Clasificación por frases
#
# 🔬 CONCLUSIONES SOBRE LA HIPÓTESIS
# ...
# ✅ HIPÓTESIS CONFIRMADA: 63.9% de opiniones son mixtas
#
# ✅ EVIDENCIA ENCONTRADA:
# • 63.9% de opiniones contienen contenido mixto
# • Las opiniones mixtas combinan información emocional y factual
# ...

# %%
# Dataset final con análisis de opiniones mixtas
columnas_relevantes = ['TituloReview', 'TotalFrases', 'FrasesSubjetivas', 'FrasesObjetivas', 'SubjetividadConFrases', 'EsMixta']

if 'ClasificacionSubjetividadConHF' in df_analisis.columns:
    columnas_relevantes.insert(-2, 'ClasificacionSubjetividadConHF')

print(f"📊 Dataset final: {len(df_analisis)} opiniones con análisis granular por frases")
df_analisis[columnas_relevantes].head(10)
# Out:
# 📊 Dataset final: 2464 opiniones con análisis granular por frases
#                                         TituloReview  TotalFrases  \
# 0  Noche diferente. Speechless. I never thought I...            7
# 1  Fun and exciting. Transportation was organized...            7
# 2  Increíble. Ninguno, me encantó toda la experie...            5
# 3  Great fun in Cancun. This is a fabulous show, ...            4
# 4  Xochimilco excelente experiencia. Joss y Rober...            4
# 5  Xoximilco increible experiencia. Fue una exper...            4
# 6  Xochimilco tiene el mejor ambiente de fiesta!!...            4
# 7  Recomendado. Visitamos este lugar para celebra...            3
# 8  Xoximilco Experience. We had the pleasure of m...            6
# 9  Genial. ¡Lo mejor que he pasado en mucho tiemp...            5
#
#    FrasesSubjetivas  FrasesObjetivas TipoOpinion  EsMixta
# 0                 7                0   Subjetivo    False
# 1                 5                2       Mixta     True
# ...

# %%
# Actualizar dataset principal con la nueva columna SubjetividadConFrases
ruta_dataset_principal = '../data/processed/dataset_opiniones_analisis.csv'

# Usar función del módulo para actualizar el dataset de manera limpia
exito = actualizar_dataset_principal(
    df_analisis=df_analisis,
    ruta_dataset_principal=ruta_dataset_principal,
    nueva_columna='SubjetividadConFrases'
)

if exito:
    print(f"\n📁 Archivo actualizado: {ruta_dataset_principal}")
else:
    print("\n❌ Error al actualizar el dataset principal")
# Out:
# ✅ Dataset principal actualizado exitosamente en: ../data/processed/dataset_opiniones_analisis.csv
# 📊 Total de registros: 2464
# 🆕 Nueva columna agregada: SubjetividadConFrases
#
# 📈 Distribución de SubjetividadConFrases:
#    Mixta: 1574 opiniones (63.9%)
#    Subjetivo: 827 opiniones (33.6%)
#    Objetivo: 63 opiniones (2.6%)
#
# 🔍 Comparación SubjetividadConHF vs SubjetividadConFrases:
# SubjetividadConFrases  Mixta  Objetivo  Subjetivo   All
# SubjetividadConHF
# Objetivo                 142        50          0   192
# Subjetivo               1432        13        827  2272
# All                     1574        63        827  2464
#
# 📋 Columnas de análisis disponibles en el dataset:
#    • SubjetividadConHF
#    • FrasesSubjetivas
#    • PorcentajeSubjetivo
#    • SubjetividadConFrases
#
# 🔄 Dataset listo para ser usado en análisis posteriores
# 📁 Archivo actualizado: ../data/processed/dataset_opiniones_analisis.csv
