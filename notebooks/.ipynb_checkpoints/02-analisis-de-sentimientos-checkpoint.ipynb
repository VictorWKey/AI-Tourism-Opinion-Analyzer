# %% [markdown]
# # Análisis de Sentimientos de Opiniones Turísticas - Todas las Ciudades
#
# Este notebook realiza un análisis comparativo de sentimientos sobre las opiniones turísticas recopiladas de **todas las ciudades**, utilizando **tres métodos diferentes** para evaluar la percepción de los visitantes sobre diferentes atracciones turísticas.
#
# ## 🎯 Objetivos del Análisis
#
# ### Análisis Principal:
# - Cargar y procesar dataset consolidado de todas las ciudades
# - Realizar análisis de sentimientos mediante tres enfoques complementarios
# - Comparar y evaluar la concordancia entre los diferentes métodos
# - Generar visualizaciones comparativas y estadísticas descriptivas
# - Exportar resultados para análisis posteriores
#
# ### Métodos de Análisis de Sentimientos:
#
# #### 1️⃣ **Método Basado en Calificaciones**
# - Mapeo directo de calificaciones de estrellas (1-5) a sentimientos
# - **Mapeo:** 4-5 estrellas → Positivo | 3 estrellas → Neutro | 1-2 estrellas → Negativo
# - **Ventaja:** Simplicidad y interpretabilidad directa
#
# #### 2️⃣ **Modelo HuggingFace - BERT Multilingüe**
# - Modelo: `nlptown/bert-base-multilingual-uncased-sentiment`
# - **Características:** Análisis basado en contenido textual, soporte multilingüe
# - **Especialización:** Sentimientos generales en reseñas y opiniones
#
# #### 3️⃣ **Modelo Cardiff NLP - Twitter XLM-RoBERTa**
# - Modelo: `cardiffnlp/twitter-xlm-roberta-base-sentiment`
# - **Características:** Optimizado para texto corto y expresivo
# - **Especialización:** Captura de emociones en textos breves (entrenado en Twitter)
#
# ## 📊 Estructura del Análisis
#
# 1. **Configuración y Carga de Datos**
# 2. **Análisis Base por Calificaciones**
# 3. **Análisis con Modelo HuggingFace**
# 4. **Análisis con Modelo Cardiff NLP**
# 5. **Comparaciones y Evaluación de Concordancia**
# 6. **Visualizaciones y Resultados**
# 7. **Exportación de Datos Procesados**
#
# ## 🔍 Resultados Esperados
# - Identificación de patrones de sentimientos por método y por ciudad
# - Análisis de concordancias y discrepancias entre enfoques
# - Evaluación de la efectividad de cada modelo en contexto turístico
# - Dataset consolidado enriquecido con múltiples clasificaciones de sentimientos

# %%
# Importación de librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Importar los módulos de análisis de sentimientos
import sys
sys.path.append('../scripts')
from sentimientos import (
    AnalizadorCalificaciones, 
    cargar_dataset_ciudad, 
    mostrar_info_dataset
)

# Configuración de visualización
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ---
#
# ## 1️⃣ Configuración y Carga de Datos
#
# En esta primera sección configuramos el entorno de trabajo y cargamos el dataset consolidado con todas las ciudades que será analizado.

# %%
# Cargar dataset consolidado con todas las ciudades
dataset_path = '../data/processed/dataset_opiniones_consolidado.csv'
df = pd.read_csv(dataset_path)

ciudades_analizadas = df['Ciudad'].unique()
print(f"📍 Ciudades: {', '.join(ciudades_analizadas)} | Filas: {df.shape[0]} | Atracciones: {df['Atraccion'].nunique()}")

df.head()
# Out:
# 📍 Ciudades: Cancun, Cdmx, Puebla, Mazatlan, Puerto_vallarta | Filas: 2464 | Atracciones: 50
#                              Titulo  \
# 0                   Noche diferente
# 1                  Fun and exciting
# 2                         Increíble
# 3               Great fun in Cancun
# 4  Xochimilco excelente experiencia
#
#                                               Review  Calificacion  \
# 0  Speechless. I never thought I'd have such a pl...             5
# 1  Transportation was organized.  Reception at th...             5
# 2  Ninguno, me encantó toda la experiencias fue i...             5
# 3  This is a fabulous show, high energy and great...             5
# 4  Joss y Roberto dieron muy buen servicio y ambi...             5
#
#   FechaEstadia  Ciudad                   Atraccion  \
# 0   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 1   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 2   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# ...

# %% [markdown]
# ---
#
# ## 2️⃣ Método 1: Análisis de Sentimientos Basado en Calificaciones
#
# El primer método utiliza un mapeo directo de las calificaciones de estrellas (1-5) a categorías de sentimientos. Este enfoque proporciona una línea base interpretable y será usado como referencia para comparar con los métodos basados en machine learning.
#
# ### Mapeo de Calificaciones:
# - **Positivo**: 4-5 estrellas (experiencias satisfactorias)
# - **Neutro**: 3 estrellas (experiencias regulares)
# - **Negativo**: 1-2 estrellas (experiencias insatisfactorias)

# %%
analizador = AnalizadorCalificaciones()

# %%
df = analizador.procesar_sentimientos_dataset(df)
df.head(8)
# Out:
#                                            Titulo  \
# 0                                 Noche diferente
# 1                                Fun and exciting
# 2                                       Increíble
# 3                             Great fun in Cancun
# 4                Xochimilco excelente experiencia
# 5                 Xoximilco increible experiencia
# 6  Xochimilco tiene el mejor ambiente de fiesta!!
# 7                                     Recomendado
#
#                                               Review  Calificacion  \
# 0  Speechless. I never thought I'd have such a pl...             5
# 1  Transportation was organized.  Reception at th...             5
# 2  Ninguno, me encantó toda la experiencias fue i...             5
# 3  This is a fabulous show, high energy and great...             5
# 4  Joss y Roberto dieron muy buen servicio y ambi...             5
# 5  Fue una experiencia maravillosa el ambiente de...             5
# ...

# %%
estadisticas = analizador.obtener_estadisticas_sentimientos(df)
analizador.mostrar_estadisticas_consola(estadisticas)

display(estadisticas['tabla_cruzada'])
display(estadisticas['por_atraccion'].head(10))
# Out:
# 📊 ESTADÍSTICAS DESCRIPTIVAS DE SENTIMIENTOS
# ...
# 🔢 DISTRIBUCIÓN DE SENTIMIENTOS:
# ----------------------------------------
#   Positivo: 2123 registros ( 86.2%)
#     Neutro: 180 registros (  7.3%)
#   Negativo: 161 registros (  6.5%)
#
# 📈 TOTAL DE REGISTROS: 2464
# Calificacion                  1   2    3    4     5   All
# SentimientoPorCalificacion
# Negativo                    101  60    0    0     0   161
# Neutro                        0   0  180    0     0   180
# Positivo                      0   0    0  463  1660  2123
# All                         101  60  180  463  1660  2464
# SentimientoPorCalificacion       Negativo  Neutro  Positivo
# Atraccion
# Acuario Interactivo                    10       7        33
# Acuario Mazatlan                       12      10        28
# Acuario Michin Ciudad De Mexico         4      28        18
# Acuario Michin Puebla                   4       5        41
# Africam Safari                          3       3        44
# ...

# %%
from sentimientos import VisualizadorSentimientos

visualizador = VisualizadorSentimientos()
# Usar la columna correcta para visualización
fig = visualizador.crear_visualizaciones_basicas(df, "Todas las ciudades", "SentimientoPorCalificacion")
plt.show()

# %%
analizador.mostrar_todos_los_ejemplos(df, n_ejemplos=3)
# Out:
# 📝 EJEMPLOS REPRESENTATIVOS DE CADA SENTIMIENTO
# ...
#
# 🎯 EJEMPLOS DE SENTIMIENTO POSITIVO
# ------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Playa Cerritos
#    ⭐ Calificación: 5/5
#    📅 Fecha: 2017-08-01
#    💬 Opinión: "una linda playa para visitar. es una de las emblemáticas playas de mazatlán lugar hermoso oleaje perfecto mazatlan es bello como sus playas conoce mazatlan."
#    --------------------------------------------------
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Plaza Machado
#    ⭐ Calificación: 5/5
#    📅 Fecha: 2023-02-01
#    💬 Opinión: "Nice Lugar. Un super lugar muy enfocado a las costumbres europeas, me enacnto todo el recorrido, la nieve y la explicacion del guia del Funbus."
#    --------------------------------------------------
#
# 📌 Ejemplo 3:
#    🏛️ Atracción: Ventura Park
#    ⭐ Calificación: 5/5
#    📅 Fecha: 2024-09-01
# ...

# %%
analizador.generar_resumen_final(df)
# Out:
# ...
# 📊 RESUMEN FINAL
# ...
# ✅ Análisis completado para 2464 opiniones
# 🏙️ Ciudades analizadas: Cancun, Cdmx, Puebla, Mazatlan, Puerto_vallarta
# 🎯 Atracciones únicas: 50
# 📈 Distribución de sentimientos:
#    • Positivo: 2123 (86.2%)
#    • Neutro: 180 (7.3%)
#    • Negativo: 161 (6.5%)
#
# 🔄 Mapeo utilizado:
#    • 4-5 estrellas → Positivo
#    • 3 estrellas → Neutro
#    • 1-2 estrellas → Negativo

# %% [markdown]
# ---
#
# ## 3️⃣ Método 2: Análisis con Modelo HuggingFace (BERT Multilingüe)
#
# En esta segunda metodología, utilizaremos un **modelo preentrenado de HuggingFace** para clasificar sentimientos basándose en el contenido textual de las opiniones de todas las ciudades. Este enfoque nos permitirá analizar la semántica y el contexto del texto, independientemente de la calificación numérica asignada.
#
# ### Características del Modelo:
# - **Modelo**: `nlptown/bert-base-multilingual-uncased-sentiment`
# - **Arquitectura**: BERT (Bidirectional Encoder Representations from Transformers)
# - **Capacidades**: Análisis multilingüe, comprensión contextual
# - **Especialización**: Análisis de sentimientos en reseñas y opiniones
#
# ### Objetivos de esta sección:
# - Aplicar análisis de sentimientos basado en procesamiento de lenguaje natural
# - Comparar resultados con el método basado en calificaciones
# - Identificar casos donde el contenido textual difiere de la calificación numérica
# - Evaluar la concordancia entre ambos enfoques
# - Generar métricas de precisión y visualizaciones comparativas

# %%
from sentimientos import AnalizadorHuggingFace

# %%
analizador_hf = AnalizadorHuggingFace(
    modelo_nombre="nlptown/bert-base-multilingual-uncased-sentiment"
)
analizador_hf.cargar_modelo()
# Out:
# 🤖 Cargando modelo: nlptown/bert-base-multilingual-uncased-sentiment
# ⏳ Esto puede tomar unos momentos la primera vez...
# Device set to use cuda:0
# ✅ Modelo cargado exitosamente
# 🌍 Modelo: nlptown/bert-base-multilingual-uncased-sentiment
# True

# %%
df_con_hf = analizador_hf.procesar_dataset_completo(df, 'TituloReview')
df_con_hf.head(10)
# Out:
# 🔄 Procesando sentimientos con HuggingFace para 2464 registros...
# ⏳ Esto puede tomar varios minutos...
#    Procesando registro 1/2464 (0.0%)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#    Procesando registro 26/2464 (1.1%)
#    Procesando registro 51/2464 (2.1%)
#    Procesando registro 76/2464 (3.1%)
#    Procesando registro 101/2464 (4.1%)
#    Procesando registro 126/2464 (5.1%)
#    Procesando registro 151/2464 (6.1%)
#    Procesando registro 176/2464 (7.1%)
#    Procesando registro 201/2464 (8.2%)
#    Procesando registro 226/2464 (9.2%)
#    Procesando registro 251/2464 (10.2%)
#    Procesando registro 276/2464 (11.2%)
#    Procesando registro 301/2464 (12.2%)
#    Procesando registro 326/2464 (13.2%)
#    Procesando registro 351/2464 (14.2%)
#    Procesando registro 376/2464 (15.3%)
#    Procesando registro 401/2464 (16.3%)
#    Procesando registro 426/2464 (17.3%)
#    Procesando registro 451/2464 (18.3%)
# ...

# %%
from sentimientos import ComparadorSentimientos

comparador = ComparadorSentimientos()
comparacion = comparador.comparar_sentimientos(df_con_hf)
comparador.mostrar_comparacion(comparacion)

display(comparacion['tabla_confusion'])
# Out:
# 📊 COMPARACIÓN: Calificación vs HuggingFace
# ...
# 🎯 CONCORDANCIA GENERAL:
#    • Total de registros: 2464
#    • Registros concordantes: 2214
#    • Porcentaje de concordancia: 89.9%
#
# 📋 ESTADÍSTICAS POR SENTIMIENTO:
# --------------------------------------------------
#
# Positivo:
#    📊 Calificación: 2123 registros
#    🔄 HuggingFace: 2065 registros
#    ✅ Concordancia: 2003 registros (94.3%)
#
# Neutro:
#    📊 Calificación: 180 registros
#    🔄 HuggingFace: 148 registros
#    ✅ Concordancia: 65 registros (36.1%)
#
# Negativo:
#    📊 Calificación: 161 registros
#    🔄 HuggingFace: 251 registros
#    ✅ Concordancia: 146 registros (90.7%)
# HuggingFace   Negativo  Neutro  Positivo   All
# Calificación
# Negativo           146       6         9   161
# Neutro              62      65        53   180
# Positivo            43      77      2003  2123
# All                251     148      2065  2464

# %%
# Crear visualización de comparación Calificación vs HuggingFace
fig_comparacion = visualizador.crear_visualizacion_comparacion(df_con_hf, comparacion)
plt.show()

print("✅ Comparación completada - Visualización mostrada arriba")
# Out:
# ✅ Comparación completada - Visualización mostrada arriba

# %%
analizador_hf.mostrar_ejemplos_discordantes(df_con_hf, n_ejemplos=3)
# Out:
# 🔍 EJEMPLOS DE DISCORDANCIAS ENTRE MÉTODOS
# ...
# 📊 Total de discordancias: 250/2464 (10.1%)
#
# 🎯 Negativo (Calificación) → Neutro (HuggingFace): 6 casos
# ------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Ultramar Cancun
#    ⭐ Calificación: 1/5 → Negativo
#    🤖 HuggingFace: Neutro
#    💬 Opinión: "Más comunicación, y que todo el personal este en la misma sintonía y más amabilidad por parte del personal........... El ferry es muy cómodo y limpio solo que siento que lo que les falta es buena comunicación por parte del personal en especial a una colaboradora que se llama Teresita Vázquez, ella da mala información, aparte siento que hay modos de como hablar ella fue muy grosera."
#    --------------------------------------------------
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Vallarta Zona Romantica
#    ⭐ Calificación: 1/5 → Negativo
#    🤖 HuggingFace: Neutro
# ...

# %%
analizador_hf.mostrar_todas_discordancias(df_con_hf)
# Out:
# 📋 LISTADO COMPLETO DE TODAS LAS DISCORDANCIAS
# ...
# 📊 Total de discordancias: 250/2464 (10.1%)
#
# 📈 Tipos de discordancia encontrados:
#    • Positivo → Neutro: 77 casos (30.8%)
#    • Neutro → Negativo: 62 casos (24.8%)
#    • Neutro → Positivo: 53 casos (21.2%)
#    • Positivo → Negativo: 43 casos (17.2%)
#    • Negativo → Positivo: 9 casos (3.6%)
#    • Negativo → Neutro: 6 casos (2.4%)
#
# ...
# 📄 LISTADO DETALLADO DE TODAS LAS DISCORDANCIAS
# ...
#
# 🎯 TIPO: Positivo (⭐Calificación) → Neutro (🤖HuggingFace)
# 📊 Total en esta categoría: 77 casos
# --------------------------------------------------------------------------------
#
# #001 | Acuario Interactivo
#      ⭐ Calificación: 4/5 → Positivo
#      🤖 HuggingFace: Neutro
#      💬 Opinión completa:
# ...

# %%
metricas = comparador.calcular_metricas_precision(df_con_hf)
comparador.mostrar_metricas_precision(metricas)
# Out:
# 📊 MÉTRICAS DE EVALUACIÓN (Comparación vs Referencia)
# ...
# SentimientoPorCalificacion Precisión  Recall     F1-Score
# --------------------------------------------------
# Positivo     0.970      0.943      0.957
# Neutro       0.439      0.361      0.396
# Negativo     0.582      0.907      0.709
# --------------------------------------------------
# PROMEDIO     0.664      0.737      0.687
#
# ℹ️  Interpretación:
#    • Precisión: % de predicciones de Comparación correctas para cada sentimiento
#    • Recall: % de casos reales detectados por Comparación
#    • F1-Score: Promedio armónico de precisión y recall

# %%
print(f"✅ Análisis completado: {len(df_con_hf)} opiniones de todas las ciudades")
print(f"🔍 Concordancia Calificación vs HuggingFace: {comparacion['porcentaje_concordancia']:.1f}%")
print(f"📊 Discordancias: {len(df_con_hf) - comparacion['concordancia_total']} de {len(df_con_hf)}")
# Out:
# ✅ Análisis completado: 2464 opiniones de todas las ciudades
# 🔍 Concordancia Calificación vs HuggingFace: 89.9%
# 📊 Discordancias: 250 de 2464

# %%
# Continuamos con el siguiente modelo, exportaremos al final todos los resultados juntos
print(f"✅ Análisis HuggingFace completado para todas las ciudades")
# Out:
# ✅ Análisis HuggingFace completado para todas las ciudades

# %% [markdown]
# ---
#
# ## 4️⃣ Método 3: Análisis con Modelo Cardiff NLP (Twitter XLM-RoBERTa)
#
# El tercer método utiliza un modelo especializado en texto corto y expresivo, entrenado específicamente en datos de Twitter. Este modelo es particularmente efectivo para capturar emociones y sentimientos en textos breves y expresivos como las reseñas turísticas de todas las ciudades.
#
# ### Características del Modelo Cardiff NLP:
# - **Modelo**: `cardiffnlp/twitter-xlm-roberta-base-sentiment`
# - **Arquitectura**: XLM-RoBERTa (Cross-lingual Language Model RoBERTa)
# - **Especialización**: Texto corto y expresivo (entrenado en Twitter)
# - **Capacidades**: Multilingüe, optimizado para captar emociones en texto breve
# - **Ventajas**: Efectivo en contenido conciso y expresivo típico de reseñas
#
# ### Análisis Comparativo en esta sección:
# - Aplicar el tercer método de análisis de sentimientos
# - Realizar comparaciones específicas:
#   - Cardiff NLP vs Calificaciones (Método 3 vs Método 1)
#   - Cardiff NLP vs HuggingFace (Método 3 vs Método 2)
# - Generar visualizaciones comparativas independientes
# - Evaluar la concordancia entre los tres métodos
# - Identificar fortalezas específicas de cada enfoque

# %%
from sentimientos import AnalizadorCardiff

analizador_cardiff = AnalizadorCardiff(
    modelo_nombre="cardiffnlp/twitter-xlm-roberta-base-sentiment"
)
analizador_cardiff.cargar_modelo()
# Out:
# 🤖 Cargando modelo Cardiff NLP: cardiffnlp/twitter-xlm-roberta-base-sentiment
# ⏳ Esto puede tomar unos momentos la primera vez...
# Device set to use cuda:0
# ✅ Modelo Cardiff NLP cargado exitosamente
# True

# %%
df_con_cardiff = analizador_cardiff.procesar_dataset_completo(df_con_hf, 'TituloReview')
df_con_cardiff.head(10)
# Out:
# 🔄 Procesando sentimientos con Cardiff NLP para 2464 registros...
# ⏳ Esto puede tomar varios minutos...
#    Procesando registro 1/2464 (0.0%)
#    Procesando registro 26/2464 (1.1%)
#    Procesando registro 51/2464 (2.1%)
#    Procesando registro 76/2464 (3.1%)
#    Procesando registro 101/2464 (4.1%)
#    Procesando registro 126/2464 (5.1%)
#    Procesando registro 151/2464 (6.1%)
#    Procesando registro 176/2464 (7.1%)
#    Procesando registro 201/2464 (8.2%)
#    Procesando registro 226/2464 (9.2%)
#    Procesando registro 251/2464 (10.2%)
#    Procesando registro 276/2464 (11.2%)
#    Procesando registro 301/2464 (12.2%)
#    Procesando registro 326/2464 (13.2%)
#    Procesando registro 351/2464 (14.2%)
#    Procesando registro 376/2464 (15.3%)
#    Procesando registro 401/2464 (16.3%)
#    Procesando registro 426/2464 (17.3%)
#    Procesando registro 451/2464 (18.3%)
#    Procesando registro 476/2464 (19.3%)
#    Procesando registro 501/2464 (20.3%)
# ...

# %%
comparacion_cardiff_cal = comparador.comparar_sentimientos(
    df_con_cardiff, 
    'SentimientoPorCalificacion', 
    'SentimientoPorCardiff',
    'Calificación',
    'Cardiff NLP'
)
comparador.mostrar_comparacion(comparacion_cardiff_cal)
display(comparacion_cardiff_cal['tabla_confusion'])
# Out:
# 📊 COMPARACIÓN: Calificación vs Cardiff NLP
# ...
# 🎯 CONCORDANCIA GENERAL:
#    • Total de registros: 2464
#    • Registros concordantes: 2080
#    • Porcentaje de concordancia: 84.4%
#
# 📋 ESTADÍSTICAS POR SENTIMIENTO:
# --------------------------------------------------
#
# Positivo:
#    📊 Calificación: 2123 registros
#    🔄 Cardiff NLP: 1968 registros
#    ✅ Concordancia: 1903 registros (89.6%)
#
# Neutro:
#    📊 Calificación: 180 registros
#    🔄 Cardiff NLP: 133 registros
#    ✅ Concordancia: 25 registros (13.9%)
#
# Negativo:
#    📊 Calificación: 161 registros
#    🔄 Cardiff NLP: 363 registros
#    ✅ Concordancia: 152 registros (94.4%)
# Cardiff NLP   Negativo  Neutro  Positivo   All
# Calificación
# Negativo           152       2         7   161
# Neutro              97      25        58   180
# Positivo           114     106      1903  2123
# All                363     133      1968  2464

# %%
# Crear visualización de comparación Cardiff vs Calificación
fig_cardiff_cal = visualizador.crear_visualizacion_comparacion_cardiff(
    df_con_cardiff, 
    comparacion_cardiff_cal, 
    columna_referencia='SentimientoPorCalificacion'
)
plt.show()

print("✅ Comparación Cardiff vs Calificación completada - Visualización mostrada arriba")
# Out:
# ✅ Comparación Cardiff vs Calificación completada - Visualización mostrada arriba

# %%
analizador_cardiff.mostrar_ejemplos_discordantes(df_con_cardiff, columna_referencia='SentimientoPorCalificacion', n_ejemplos=3)
analizador_cardiff.mostrar_todas_discordancias(df_con_cardiff, columna_referencia='SentimientoPorCalificacion')
# Out:
# 🔍 EJEMPLOS DE DISCORDANCIAS: CARDIFF NLP vs SENTIMIENTOPORCALIFICACION
# ...
# 📊 Total de discordancias: 384/2464 (15.6%)
#
# 🎯 Negativo (SentimientoPorCalificacion) → Neutro (Cardiff): 2 casos
# ------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Isla De Los Venados
#    ⭐ Calificación: 2/5
#    🔄 SentimientoPorCalificacion: Negativo
#    🐦 Cardiff NLP: Neutro
# ...

# %%
comparacion_hf_cardiff = comparador.comparar_sentimientos(
    df_con_cardiff, 
    'SentimientoPorHF', 
    'SentimientoPorCardiff',
    'HuggingFace',
    'Cardiff NLP'
)
comparador.mostrar_comparacion(comparacion_hf_cardiff)
display(comparacion_hf_cardiff['tabla_confusion'])
# Out:
# 📊 COMPARACIÓN: HuggingFace vs Cardiff NLP
# ...
# 🎯 CONCORDANCIA GENERAL:
#    • Total de registros: 2464
#    • Registros concordantes: 2144
#    • Porcentaje de concordancia: 87.0%
#
# 📋 ESTADÍSTICAS POR SENTIMIENTO:
# --------------------------------------------------
#
# Positivo:
#    📊 HuggingFace: 2065 registros
#    🔄 Cardiff NLP: 1968 registros
#    ✅ Concordancia: 1893 registros (91.7%)
#
# Neutro:
#    📊 HuggingFace: 148 registros
#    🔄 Cardiff NLP: 133 registros
#    ✅ Concordancia: 27 registros (18.2%)
#
# Negativo:
#    📊 HuggingFace: 251 registros
#    🔄 Cardiff NLP: 363 registros
#    ✅ Concordancia: 224 registros (89.2%)
# Cardiff NLP  Negativo  Neutro  Positivo   All
# HuggingFace
# Negativo          224      12        15   251
# Neutro             61      27        60   148
# Positivo           78      94      1893  2065
# All               363     133      1968  2464

# %%
# Crear visualización de comparación HuggingFace vs Cardiff
fig_hf_cardiff = visualizador.crear_visualizacion_comparacion_cardiff(
    df_con_cardiff, 
    comparacion_hf_cardiff, 
    columna_referencia='SentimientoPorHF'
)
plt.show()

print("✅ Comparación HuggingFace vs Cardiff completada - Visualización mostrada arriba")
# Out:
# ✅ Comparación HuggingFace vs Cardiff completada - Visualización mostrada arriba

# %%
analizador_cardiff.mostrar_ejemplos_discordantes(df_con_cardiff, columna_referencia='SentimientoPorHF', n_ejemplos=3)
analizador_cardiff.mostrar_todas_discordancias(df_con_cardiff, columna_referencia='SentimientoPorHF')
# Out:
# 🔍 EJEMPLOS DE DISCORDANCIAS: CARDIFF NLP vs SENTIMIENTOPORHF
# ...
# 📊 Total de discordancias: 320/2464 (13.0%)
#
# 🎯 Negativo (SentimientoPorHF) → Neutro (Cardiff): 12 casos
# ------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Museo Soumaya
#    ⭐ Calificación: 3/5
#    🔄 SentimientoPorHF: Negativo
#    🐦 Cardiff NLP: Neutro
#    💬 Opinión: "Usted recibe lo que paga, supongo. La entrada es gratuita, así que no esperes ningún servicio al cliente. El encargado del equipaje literalmente nos dio actitud solo porque hicimos una pregunta. No estábamos desafiando o quejándonos del protocolo, simplemente teníamos curiosidad de por qué era protocolo en primer lugar. Si la curiosidad alguna vez mató al gato, fue por el resplandor que salía de los ojos del encargado de la maleta."
#    --------------------------------------------------
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Castillo De Chapultepec
#    ⭐ Calificación: 3/5
#    🔄 SentimientoPorHF: Negativo
# ...

# %%
# Crear visualización de comparación de los tres modelos
fig_tres_metodos = visualizador.crear_visualizacion_comparacion_tres_modelos(df_con_cardiff)
if fig_tres_metodos:
    plt.show()
    print("✅ Análisis de tres modelos completado - Visualización mostrada arriba")
else:
    print("❌ Error al crear la visualización de tres modelos")
# Out:
# ✅ Análisis de tres modelos completado - Visualización mostrada arriba

# %% [markdown]
# ---
#
# ## 5️⃣ Análisis Comparativo Global
#
# En esta sección realizamos un análisis comparativo comprehensivo de los tres métodos evaluados, proporcionando una visión global de su rendimiento y concordancia.

# %%
ciudades = df_con_cardiff['Ciudad'].unique()

# Calcular concordancias entre pares y concordancia perfecta entre los tres métodos de forma vectorizada
concordancias = {
    "cal_hf": (df_con_cardiff['SentimientoPorCalificacion'] == df_con_cardiff['SentimientoPorHF']),
    "cal_cardiff": (df_con_cardiff['SentimientoPorCalificacion'] == df_con_cardiff['SentimientoPorCardiff']),
    "hf_cardiff": (df_con_cardiff['SentimientoPorHF'] == df_con_cardiff['SentimientoPorCardiff']),
    "total_tres": (df_con_cardiff['SentimientoPorCalificacion'] == df_con_cardiff['SentimientoPorHF']) & 
                   (df_con_cardiff['SentimientoPorCalificacion'] == df_con_cardiff['SentimientoPorCardiff'])
}

# Calcular porcentajes de concordancia
resultados_concordancia = {k: v.mean() * 100 for k, v in concordancias.items()}

# Resumen final
print(f"📊 RESUMEN FINAL - Todas las ciudades")
print(f"✅ Opiniones analizadas: {len(df_con_cardiff)} | Atracciones: {df_con_cardiff['Atraccion'].nunique()}")
print(f"🏙️ Ciudades: {', '.join(ciudades)}")
print(f"\n🔍 Concordancias entre pares:")
print(f"   🎯 Calificación vs HuggingFace: {resultados_concordancia['cal_hf']:.1f}%")
print(f"   🎯 Calificación vs Cardiff NLP: {resultados_concordancia['cal_cardiff']:.1f}%")
print(f"   🎯 HuggingFace vs Cardiff NLP: {resultados_concordancia['hf_cardiff']:.1f}%")
print(f"\n✨ Concordancia perfecta (3 métodos): {resultados_concordancia['total_tres']:.1f}%")
# Out:
# 📊 RESUMEN FINAL - Todas las ciudades
# ✅ Opiniones analizadas: 2464 | Atracciones: 50
# 🏙️ Ciudades: Cancun, Cdmx, Puebla, Mazatlan, Puerto_vallarta
#
# 🔍 Concordancias entre pares:
#    🎯 Calificación vs HuggingFace: 89.9%
#    🎯 Calificación vs Cardiff NLP: 84.4%
#    🎯 HuggingFace vs Cardiff NLP: 87.0%
#
# ✨ Concordancia perfecta (3 métodos): 81.7%

# %%
from sentimientos import exportar_dataset_consolidado_analisis

exportar_dataset_consolidado_analisis(df_con_cardiff)
print(f"✅ Dataset consolidado exportado con los 3 métodos de análisis de sentimientos")
# Out:
# ✅ Dataset consolidado de análisis exportado exitosamente
# 📁 Archivo: dataset_opiniones_analisis.csv
# 📍 Ubicación: ../data/processed/dataset_opiniones_analisis.csv
# 📊 Registros: 2464
# 🏙️ Ciudades incluidas: Cancun, Cdmx, Puebla, Mazatlan, Puerto_vallarta
# 🎯 Atracciones únicas: 50
# 🤖 Análisis incluidos: Calificación + HuggingFace + Cardiff NLP
# 📋 Total de columnas: 10
# 💾 Listo para usar en futuros notebooks
# ✅ Dataset consolidado exportado con los 3 métodos de análisis de sentimientos
