# %% [markdown]
# # Análisis de Subjetividad de Opiniones Turísticas
#
# Este notebook realiza un análisis de subjetividad sobre las opiniones turísticas utilizando modelos preentrenados de HuggingFace para clasificar texto en: **Subjetivo vs Objetivo**.
#
# ## Objetivos:
# - Aplicar modelo multilingüe especializado en análisis de subjetividad
# - Generar estadísticas descriptivas y visualizaciones
# - Analizar relación entre subjetividad y sentimientos (si están disponibles)
#
# ## Modelo utilizado:
# - **GroNLP/mdebertav3-subjectivity-multilingual**: Modelo multilingüe especializado en análisis de subjetividad

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Cargar dataset con análisis de sentimientos
dataset_path_analisis = '../data/processed/dataset_opiniones_analisis.csv'

df = pd.read_csv(dataset_path_analisis)
ciudad = df['Ciudad'].iloc[0]

print(f"📍 Ciudad: {ciudad} | Filas: {df.shape[0]}")
df[['TituloReview', 'Calificacion', 'SentimientoPorHF']].head()
# Out:
# 📍 Ciudad: Cancun | Filas: 2464
#                                         TituloReview  Calificacion  \
# 0  Noche diferente. Speechless. I never thought I...             5
# 1  Fun and exciting. Transportation was organized...             5
# 2  Increíble. Ninguno, me encantó toda la experie...             5
# 3  Great fun in Cancun. This is a fabulous show, ...             5
# 4  Xochimilco excelente experiencia. Joss y Rober...             5
#
#   SentimientoPorHF
# 0         Positivo
# 1         Positivo
# 2         Positivo
# 3         Positivo
# 4         Positivo

# %%
import sys
sys.path.append('../scripts')
from subjetividad import AnalizadorHuggingFaceSubjetividad

analizador = AnalizadorHuggingFaceSubjetividad(
    modelo_nombre="GroNLP/mdebertav3-subjectivity-multilingual"
)
analizador.cargar_modelo()
# Out:
# Device set to use cuda:0
# True

# %%
# Probar el modelo con algunos ejemplos
ejemplos_prueba = [
    "Me encantó este lugar, es increíble y lo recomiendo mucho",
    "El museo abre de 9:00 AM a 6:00 PM todos los días",
    "Qué experiencia tan horrible, no vuelvo nunca más"
]

for ejemplo in ejemplos_prueba:
    resultado = analizador.analizar_subjetividad_texto(ejemplo)
    print(f"'{ejemplo[:40]}...' → {resultado['categoria']}")
# Out:
# 'Me encantó este lugar, es increíble y lo...' → Subjetivo
# 'El museo abre de 9:00 AM a 6:00 PM todos...' → Objetivo
# 'Qué experiencia tan horrible, no vuelvo ...' → Subjetivo

# %%
df_con_subjetividad = analizador.procesar_dataset_completo(df, 'TituloReview')

df_con_subjetividad[['TituloReview', 'Calificacion', 'SubjetividadConHF']].head(10)
# Out:
#                                         TituloReview  Calificacion  \
# 0  Noche diferente. Speechless. I never thought I...             5
# 1  Fun and exciting. Transportation was organized...             5
# 2  Increíble. Ninguno, me encantó toda la experie...             5
# 3  Great fun in Cancun. This is a fabulous show, ...             5
# 4  Xochimilco excelente experiencia. Joss y Rober...             5
# 5  Xoximilco increible experiencia. Fue una exper...             5
# 6  Xochimilco tiene el mejor ambiente de fiesta!!...             5
# 7  Recomendado. Visitamos este lugar para celebra...             5
# 8  Xoximilco Experience. We had the pleasure of m...             5
# 9  Genial. ¡Lo mejor que he pasado en mucho tiemp...             5
#
#   SubjetividadConHF
# 0         Subjetivo
# 1         Subjetivo
# 2         Subjetivo
# 3         Subjetivo
# 4         Subjetivo
# 5         Subjetivo
# 6         Subjetivo
# 7         Subjetivo
# 8         Subjetivo
# 9         Subjetivo

# %%
estadisticas = analizador.obtener_estadisticas_subjetividad(df_con_subjetividad)
analizador.mostrar_estadisticas_consola(estadisticas)

display(estadisticas['por_atraccion'].head(10))
# Out:
# 📊 ESTADÍSTICAS DESCRIPTIVAS DE SUBJETIVIDAD
# ============================================================
# 🔢 DISTRIBUCIÓN DE SUBJETIVIDAD:
# ----------------------------------------
#  Subjetivo: 2272 registros ( 92.2%)
#   Objetivo: 192 registros (  7.8%)
#
# 📈 TOTAL DE REGISTROS: 2464
#
# 📝 DESCRIPCIÓN DE CATEGORÍAS:
# ----------------------------------------
#  Subjetivo: Texto que expresa opiniones, emociones, evaluaciones personales
#   Objetivo: Texto que presenta hechos, información factual sin opiniones
# SubjetividadConHF                Objetivo  Subjetivo
# Atraccion
# Acuario Interactivo                     3         47
# Acuario Mazatlan                        0         50
# Acuario Michin Ciudad De Mexico         1         49
# Acuario Michin Puebla                   1         49
# Africam Safari                          0         50
# Avenida Kukulkan                        7         43
# Basilica De La Virgen Guadalupe         5         45
# Callejon De Los Sapos                   1         49
# Capilla Del Rosario                     0         50
# Castillo De Chapultepec                 5         35

# %%
from subjetividad import VisualizadorSubjetividad
import matplotlib.pyplot as plt

visualizador = VisualizadorSubjetividad()
ciudad = df_con_subjetividad['Ciudad'].iloc[0]

fig_basicas = visualizador.crear_visualizaciones_basicas(df_con_subjetividad, ciudad)
plt.show()

# %%
fig_detalladas = visualizador.crear_visualizacion_detallada(df_con_subjetividad, ciudad)
plt.show()

# %% [markdown]
# # Análisis Combinado: Subjetividad vs Sentimientos
#
# En esta sección analizaremos la relación entre la subjetividad del texto y los sentimientos expresados. Esto nos permitirá entender:
#
# - **¿El texto subjetivo tiende a ser más positivo o negativo?**
# - **¿El texto objetivo mantiene neutralidad en los sentimientos?**
# - **¿Cómo se distribuyen los sentimientos dentro de cada categoría de subjetividad?**
# - **¿Existe correlación entre ser subjetivo y expresar sentimientos extremos?**
#
# Este análisis combinado nos dará una visión más completa del comportamiento emocional y la objetividad en las opiniones turísticas.

# %%
estadisticas_combinadas = analizador.analizar_subjetividad_por_sentimientos(df_con_subjetividad)
analizador.mostrar_estadisticas_subjetividad_sentimientos(estadisticas_combinadas)
# Out:
# 📊 ANÁLISIS DE SUBJETIVIDAD vs SENTIMIENTOS
# ============================================================
# 📈 Total de registros analizados: 2464
# 📝 Texto subjetivo: 2272 (92.2%)
# 📋 Texto objetivo: 192 (7.8%)
#
# 📋 TABLA CRUZADA COMPLETA:
# ----------------------------------------
# SentimientoPorHF   Negativo  Neutro  Positivo   All
# SubjetividadConHF
# Objetivo                 15      26       151   192
# Subjetivo               236     122      1914  2272
# All                     251     148      2065  2464
#
# 📊 DISTRIBUCIÓN PORCENTUAL POR SUBJETIVIDAD:
# --------------------------------------------------
# SentimientoPorHF   Negativo  Neutro  Positivo
# SubjetividadConHF
# Objetivo                7.8    13.5      78.6
# Subjetivo              10.4     5.4      84.2
#
# 🔍 SENTIMIENTOS EN TEXTO SUBJETIVO:
# ----------------------------------------
#    • Positivo: 1914 (84.2%)
#    • Negativo: 236 (10.4%)
#    • Neutro: 122 (5.4%)
#
# 🔍 SENTIMIENTOS EN TEXTO OBJETIVO:
# ----------------------------------------
#    • Positivo: 151 (78.6%)
#    • Neutro: 26 (13.5%)
#    • Negativo: 15 (7.8%)
#
# ⭐ CALIFICACIONES PROMEDIO POR COMBINACIÓN:
# --------------------------------------------------
#    • Objetivo + Negativo: 3.3 estrellas
#    • Objetivo + Neutro: 3.6 estrellas
#    • Objetivo + Positivo: 4.5 estrellas
#    • Subjetivo + Negativo: 2.2 estrellas
#    • Subjetivo + Neutro: 3.6 estrellas
#    • Subjetivo + Positivo: 4.8 estrellas
#
# 💡 INSIGHTS PRINCIPALES:
# ------------------------------
# • El 84.2% del texto subjetivo es Positivo
# • El 78.6% del texto objetivo es Positivo
# • El texto subjetivo tiende a ser más positivo (84.2% vs 78.6%)

# %%
fig_combinado = visualizador.crear_visualizacion_subjetividad_vs_sentimientos(df_con_subjetividad, ciudad)
plt.show()

# %%
sentimientos = df_con_subjetividad['SentimientoPorHF'].unique()

for sentimiento in sentimientos:
    df_sentimiento = df_con_subjetividad[df_con_subjetividad['SentimientoPorHF'] == sentimiento]
    total_sentimiento = len(df_sentimiento)
    
    print(f"\n🎯 {sentimiento.upper()}: {total_sentimiento} opiniones")
    
    subjetividad_en_sentimiento = df_sentimiento['SubjetividadConHF'].value_counts()
    for subj_tipo, cantidad in subjetividad_en_sentimiento.items():
        porcentaje = (cantidad / total_sentimiento) * 100
        print(f"   • {subj_tipo}: {cantidad} ({porcentaje:.1f}%)")
# Out:
# 🎯 POSITIVO: 2065 opiniones
#    • Subjetivo: 1914 (92.7%)
#    • Objetivo: 151 (7.3%)
#
# 🎯 NEGATIVO: 251 opiniones
#    • Subjetivo: 236 (94.0%)
#    • Objetivo: 15 (6.0%)
#
# 🎯 NEUTRO: 148 opiniones
#    • Subjetivo: 122 (82.4%)
#    • Objetivo: 26 (17.6%)

# %%
analizador.mostrar_ejemplos_categoria(df_con_subjetividad, categoria='Subjetivo', n_ejemplos=3)
# Out:
# 🎯 EJEMPLOS DE TEXTO SUBJETIVO
# ----------------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Acuario Michin Puebla
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Fue muy WOW mi experiencia ya que me fascinan las especies. Las especies, el personal y actividades, el asombro de las especies es muy espectacular ya que hay bastantes y muy variadas más aparte la comida que puedes encontrar."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Basilica De La Virgen Guadalupe
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Sacred site worth visiting. I was raised Catholic but no longer practice.  Still you needn't be religious to find that this site is worth the trip and an hour or two of your time.  It's really a huge complex.  The new basilica houses the image of the virgin, which is located behind the altar.  Visit all of the churches/chapels to get the complete picture and to enjoy the views of the city."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 3:
#    🏛️ Atracción: El Faro De Mazatlan
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Vista increíble. Se requiere de buena condición física para escalar hasta la cima y apreciar la mejor y  más bella vista del puerto."
#    🏷️ Categoría: Subjetivo

# %%
analizador.mostrar_ejemplos_categoria(df_con_subjetividad, categoria='Objetivo', n_ejemplos=3)
# Out:
# 🎯 EJEMPLOS DE TEXTO OBJETIVO
# ----------------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Museo Frida Kahlo
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Mexican feminist is renowned artist. Frida Kahlo (1907-1954) was eminent Mexican artist who married Diego Rivero, a famous painter. Frida Kahlo is known for her self-portraits and her paintings of natural Mexican subjects. Frida Kahlo is known for her unique beauty; she suffered from polio and accidents but emerged as one of the great feminist artists of the 20th Century. Many of her works are held in public collections in Mexico and overseas."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Castillo De Chapultepec
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "A Beautiful Day at Chapultepec!. When I checked online, it showed that tickets to Chapultepec Castle were sold out, and I was initially quite disappointed. But we decided to visit Chapultepec Park anyway—and I’m so glad we did!The park is absolutely beautiful, with lovely shaded paths and so much greenery. A real highlight was feeding the squirrels—such a unique and joyful experience that we’d never get to do back home.As we explored, we also stopped by the Anthropology Museum, which was stunning and incredibly vast. While the exhibits were impressive, most of the information was in Spanish, so we couldn’t fully appreciate everything.Eventually, we made our way to Chapultepec Castle, and to our surprise, they were selling tickets at the entrance! We bought them and went in right away. Just a heads-up—the walk up to the castle is fairly steep and long, so wear comfortable shoes and be prepared for a bit of a workout.The castle itself is beautiful, filled with rich history and artifacts. I’m really glad we didn’t give up and decided to walk up to the entrance anyway.Important tip: No food or water is allowed inside. They check bags at the top, and if you’ve brought any, they’ll ask you to throw it away—even if you’ve made it past the entrance. Lockers are available at the bottom, so it’s best to store your items there before heading up."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 3:
#    🏛️ Atracción: Isla De La Piedras
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Pasé un mes en la zona. Stoney isla era nuestro lugar Go To para relajarse en la playa. Si compraste comida y bebidas. Tienes un paraguas y sillas de los restaurantes. La comida y las bebidas eran buenas. Menos vendedores y ruido que las principales playas."
#    🏷️ Categoría: Objetivo

# %%
analizador.mostrar_todos_los_ejemplos(df_con_subjetividad, n_ejemplos=5)
# Out:
# 🔍 EJEMPLOS REPRESENTATIVOS POR CATEGORÍA DE SUBJETIVIDAD
# ======================================================================
#
# 🎯 EJEMPLOS DE TEXTO SUBJETIVO
# ----------------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: Acuario Michin Puebla
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Experiencia única. El lugar ha superado mis expectativas,  está lleno de muchas experiencias increíbles, además de que el personal es súper amable. ✨️."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Vallarta Parroquia De Nuestra Señora De Guadalupe
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Beautiful Cathedral. Easy to stop in and see while on your visit to the boardwalk.  Beautiful architecture!  Well worth the short time it takes to view this beautiful piece of history."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 3:
#    🏛️ Atracción: Vallarta San Pancho
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Ambiente relajado. Esta pequeña ciudad cerca de Sayulita es ideal para caminar, ir al mercado artesanal y surfear. Debes verlo."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 4:
#    🏛️ Atracción: Playa Tortugas
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Gran playa. Una gran playa pública con puerto marítimo, es un lugar tranquilo y la arena blanca hace que los colores del mar sean sensacionales, con restaurantes y bares donde alimentarse y pasar un día genial."
#    🏷️ Categoría: Subjetivo
#
# 📌 Ejemplo 5:
#    🏛️ Atracción: Mercado El Parian
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Un mercado de artesanías con todo. Es un lugar ordenado, limpio, donde se consigue todo tipo de artesanías a un buen precio, vale la pena."
#    🏷️ Categoría: Subjetivo
#
# 🎯 EJEMPLOS DE TEXTO OBJETIVO
# ----------------------------------------------------------------------
#
# 📌 Ejemplo 1:
#    🏛️ Atracción: La Isla
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Has what we needed. This was the center of our activities outside of our resort. It has multiple sections like luxury, fashion, entertainment and dining.  With armed security guards on patrol we felt very safe here.What made this shopping mall special for us was the number and variety of restaurants. We ate at one almost every night of our trip."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 2:
#    🏛️ Atracción: Basilica De La Virgen Guadalupe
#    ⭐ Calificación: 5 estrellas
#    📝 Texto completo:
#       "Basilica provided English speaking tour arranged ahead of time. Ahead of our first-time visit, I booked a private tour for our group of 3 couples via the Basilica's website. Ms. Gabriela can be reached at visitasguiadas@inbg.mx - she is an English-speaking volunteer for the Basilica - she requests a very modest financial gift   be made at the Basilica office at the beginning of the Tour.  It was really worth it to have Gabriela's guided visit of the entire complex. Note, there are elevations to climb (3 in our group opted not to climb to the top of the hill to see the Parish of the Indians) but it is totally worth the effort! We are all Catholics and after our tour attended 4pm Mass in the old Basilica.At the conclusion of the tour, Gabriela gave each couple a packet of additional information. Note, you can NOT be late to her assigned time, again, because she is a volunteer. And we also chose to generously tip Gabriela for her time and guidance. Note, we had a wonderful private driver that day bring our group from the Anthropology Museum to the Basilica entrance and wait for us. He speaks very good English and drove a large vehicle comfortable for our 6. See my review of Gran Hotel for his contact information.Also, give yourself more than 2 hours (we spent 3 and I wish I had more time!) to visit.Lastly, please, please, please dress in a MODEST way as this is a place of consecrated churches."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 3:
#    🏛️ Atracción: Playa Cerritos
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Tranquila!. Es una playa pequeña, de oleaje medio, es de las más tranquilas de Mazatlán. Hay varios restaurantes, pero también puede uno traer sus propias cosas."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 4:
#    🏛️ Atracción: Zocalo De Puebla
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Cerrado parcialmente. El zócalo de la ciudad de Puebla es muy agradable para caminar, para sentarse a ver pasar a la gente, asearse el calzado."
#    🏷️ Categoría: Objetivo
#
# 📌 Ejemplo 5:
#    🏛️ Atracción: Vallarta Marina Vallarta
#    ⭐ Calificación: 4 estrellas
#    📝 Texto completo:
#       "Limpie con un paseo marítimo ancho y pavimentado. Es un puerto deportivo con hermosos barcos y un faro interesante. Los jueves por la noche, se llena mucho porque hay un mercado con vendedores que venden artesanías y una variedad de alimentos. Hay varios restaurantes a lo largo de aquí y una serie de centros turísticos a poca distancia. ¡Nunca habíamos visto tantas farmacias en un mismo lugar tan cerca unas de otras!."
#    🏷️ Categoría: Objetivo

# %%
# Tabla cruzada subjetividad vs calificaciones
tabla_cruzada = pd.crosstab(df_con_subjetividad['SubjetividadConHF'], df_con_subjetividad['Calificacion'], margins=True)
display(tabla_cruzada)

tabla_porcentual = pd.crosstab(df_con_subjetividad['SubjetividadConHF'], df_con_subjetividad['Calificacion'], normalize='columns') * 100
display(tabla_porcentual.round(1))
# Out:
# Calificacion         1   2    3    4     5   All
# SubjetividadConHF
# Objetivo             2   5   24   70    91   192
# Subjetivo           99  55  156  393  1569  2272
# All                101  60  180  463  1660  2464
# Calificacion          1     2     3     4     5
# SubjetividadConHF
# Objetivo            2.0   8.3  13.3  15.1   5.5
# Subjetivo          98.0  91.7  86.7  84.9  94.5

# %%
analizador.generar_resumen_final(df_con_subjetividad)
# Out:
#  RESUMEN FINAL
# ======================================================================
# ✅ Análisis de subjetividad completado exitosamente
# 🏙️ Ciudad analizada: Cancun
# 📊 Total de opiniones analizadas: 2464
# 🎯 Atracciones únicas: 50
# 🤖 Modelo utilizado: GroNLP/mdebertav3-subjectivity-multilingual
# 📊 ESTADÍSTICAS DESCRIPTIVAS DE SUBJETIVIDAD
# ============================================================
# 🔢 DISTRIBUCIÓN DE SUBJETIVIDAD:
# ----------------------------------------
#  Subjetivo: 2272 registros ( 92.2%)
#   Objetivo: 192 registros (  7.8%)
#
# 📈 TOTAL DE REGISTROS: 2464
#
# 📝 DESCRIPCIÓN DE CATEGORÍAS:
# ----------------------------------------
#  Subjetivo: Texto que expresa opiniones, emociones, evaluaciones personales
#   Objetivo: Texto que presenta hechos, información factual sin opiniones
# ======================================================================

# %% [markdown]
# Hipotesis: tenemos muy pocas opiniones objetivas debido a que las personas suelen tener una opinion mixta.
#
# Se validara en el siguiente notebook

# %%
# Sobrescribir el dataset original agregando la columna SubjetividadConHF
import pandas as pd

ruta_dataset_original = '../data/processed/dataset_opiniones_analisis.csv'

# Verificar que tenemos la columna SubjetividadConHF
if 'SubjetividadConHF' not in df_con_subjetividad.columns:
    print("❌ Error: La columna SubjetividadConHF no se encontró en el dataset")
else:
    # Sobrescribir el archivo original agregando la nueva columna
    df_con_subjetividad.to_csv(ruta_dataset_original, index=False, encoding='utf-8')
    
    print(f"✅ Dataset original actualizado en: {ruta_dataset_original}")
    print(f"📊 Total de registros: {len(df_con_subjetividad)}")
    print(f"📋 Columnas incluidas: {list(df_con_subjetividad.columns)}")
    
    # Mostrar distribución de la nueva columna
    distribucion_subjetividad = df_con_subjetividad['SubjetividadConHF'].value_counts()
    print(f"\n📈 Distribución de subjetividad:")
    for categoria, cantidad in distribucion_subjetividad.items():
        porcentaje = (cantidad / len(df_con_subjetividad)) * 100
        print(f"   {categoria}: {cantidad} opiniones ({porcentaje:.1f}%)")
    
    print(f"\n✅ El dataset ahora incluye la columna 'SubjetividadConHF' y está listo para uso en análisis posteriores")
# Out:
# ✅ Dataset original actualizado en: ../data/processed/dataset_opiniones_analisis.csv
# 📊 Total de registros: 2464
# 📋 Columnas incluidas: ['Titulo', 'Review', 'Calificacion', 'FechaEstadia', 'Ciudad', 'Atraccion', 'TituloReview', 'SentimientoPorCalificacion', 'SentimientoPorHF', 'SentimientoPorCardiff', 'SubjetividadConHF']
#
# 📈 Distribución de subjetividad:
#    Subjetivo: 2272 opiniones (92.2%)
#    Objetivo: 192 opiniones (7.8%)
#
# ✅ El dataset ahora incluye la columna 'SubjetividadConHF' y está listo para uso en análisis posteriores
