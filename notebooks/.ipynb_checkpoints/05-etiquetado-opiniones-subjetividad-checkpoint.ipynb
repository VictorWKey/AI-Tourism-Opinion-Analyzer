# %% [markdown]
# # Etiquetado de Opiniones por Subjetividad
#
# Este notebook implementa un sistema de clasificación automática de reseñas turísticas en tres categorías:
# - **Objetiva**: contiene únicamente hechos verificables
# - **Subjetiva**: contiene opiniones, juicios personales o sentimientos
# - **Mixta**: combina hechos verificables con opiniones
#
# Utiliza LangChain con GPT-4o-mini para realizar la clasificación con structured output.

# %%
# Importaciones necesarias
import sys
import os

# Añadir el directorio scripts al path
sys.path.append('../scripts')

# Importar módulo de etiquetado personalizado
from etiquetado import (
    configurar_entorno, validar_dependencias, verificar_api_key,
    cargar_datasets, configurar_clasificador, proceso_completo_clasificacion,
    mostrar_opiniones_por_categoria, mostrar_ejemplos_detallados, analisis_avanzado_frases
)

# Configurar entorno
configurar_entorno()
validar_dependencias()
# Out:
# True

# %%
# Verificar configuración de API
verificar_api_key()
# Out:
# True

# %%
# Cargar datasets y verificar estado
resultado_carga = cargar_datasets(verificar_existentes=True)
df_reviews, df_existente, necesita_clasificacion = resultado_carga
# Out:
# ✅ Dataset de análisis cargado desde: ../data/processed/dataset_opiniones_analisis.csv
# 📊 Total de registros: 2464
# 🔍 Dataset ya contiene clasificación LLM

# %%
# Configurar clasificador
clasificador = configurar_clasificador()

# %%
# Ejecutar clasificación completa
df_clasificado, df_analizado, guardado_exitoso = proceso_completo_clasificacion(
    df_reviews, clasificador, df_existente
)
# Out:
# � Análisis de 2464 reseñas clasificadas
#
# 🏷️ DISTRIBUCIÓN GENERAL:
#    Objetiva: 21 reseñas (0.9%)
#    Subjetiva: 630 reseñas (25.6%)
#    Mixta: 1813 reseñas (73.6%)
#
# 🌎 POR CIUDAD:
#
#   📍 Cancun:
#      Objetiva: 7 reseñas (1.4%)
#      Subjetiva: 135 reseñas (28.0%)
#      Mixta: 341 reseñas (70.6%)
#
#   📍 Cdmx:
#      Objetiva: 3 reseñas (0.6%)
#      Subjetiva: 103 reseñas (21.0%)
#      Mixta: 384 reseñas (78.4%)
#
#   📍 Puebla:
#      Objetiva: 3 reseñas (0.6%)
#      Subjetiva: 172 reseñas (34.4%)
#      Mixta: 325 reseñas (65.0%)
#
#   📍 Mazatlan:
#      Objetiva: 1 reseñas (0.2%)
#      Subjetiva: 108 reseñas (21.6%)
#      Mixta: 391 reseñas (78.2%)
#
#   📍 Puerto_vallarta:
#      Objetiva: 7 reseñas (1.4%)
#      Subjetiva: 112 reseñas (22.8%)
#      Mixta: 372 reseñas (75.8%)

# %%
# Mostrar resumen del análisis
df_analizado.head()
# Out:
#                              Titulo  \
# 0                   Noche diferente
# 1                  Fun and exciting
# 2                         Increíble
# 3               Great fun in Cancun
# 4  Xochimilco excelente experiencia
#
#                                               Review  Calificacion  \
# 0  Speechless. I never thought I'd have such a pl...             5
# 1  Transportation was organized.  Reception at th...             5
# 2  Ninguno, me encantó toda la experiencias fue i...             5
# 3  This is a fabulous show, high energy and great...             5
# 4  Joss y Roberto dieron muy buen servicio y ambi...             5
#
#   FechaEstadia  Ciudad                   Atraccion  \
# 0   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 1   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 2   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 3   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
# 4   2025-08-01  Cancun  Xoximilco Cancun By Xcaret
#
#                                         TituloReview  \
# 0  Noche diferente. Speechless. I never thought I...
# 1  Fun and exciting. Transportation was organized...
# 2  Increíble. Ninguno, me encantó toda la experie...
# 3  Great fun in Cancun. This is a fabulous show, ...
# 4  Xochimilco excelente experiencia. Joss y Rober...
#
#   SentimientoPorCalificacion SentimientoPorHF SentimientoPorCardiff  \
# 0                   Positivo         Positivo              Positivo
# 1                   Positivo         Positivo              Positivo
# 2                   Positivo         Positivo              Positivo
# 3                   Positivo         Positivo              Positivo
# 4                   Positivo         Positivo              Positivo
#
#   SubjetividadConHF  TotalFrases  FrasesSubjetivas  FrasesObjetivas  \
# 0         Subjetivo            7                 7                0
# 1         Subjetivo            7                 5                2
# 2         Subjetivo            5                 4                1
# 3         Subjetivo            4                 4                0
# 4         Subjetivo            4                 3                1
#
#   TipoOpinion  EsMixta  PorcentajeSubjetivo  PorcentajeObjetivo  \
# 0   Subjetivo    False           100.000000            0.000000
# 1       Mixta     True            71.428571           28.571429
# 2       Mixta     True            80.000000           20.000000
# 3   Subjetivo    False           100.000000            0.000000
# 4       Mixta     True            75.000000           25.000000
#
#   SubjetividadConFrases SubjetividadConLLM
# 0             Subjetivo          Subjetiva
# 1                 Mixta              Mixta
# 2                 Mixta          Subjetiva
# 3             Subjetivo              Mixta
# 4                 Mixta              Mixta

# %%
# Mostrar ejemplos de opiniones por categoría
mostrar_opiniones_por_categoria(df_clasificado)
# Out:
# 📋 Ejemplos por categoría:
# ==============================
#
# 🏷️ Objetiva:
#    1. Great location. Convenient location. Main road, easy access to local bus routes, tourist places, shopping centers, restaurants, activities and hotels.
#    2. Un símbolo de la zona hotelera y de todo Cancún. La avenida Kukulcán a lo largo de sus 26 kms. une todos los hoteles de la zona hotelera de norte a sur, inicia saliendo de Cancún y termina cerca del acceso al aeropuerto. Las numerosas líneas de "camiones" (ómnibus) trasladan a los turistas de los hoteles más distantes a la zona más céntrica y viceversa.
#    3. Conexiones. Esta avenida conecta la zona hotelera, shoppings, casas de cambio, propuestas gastronómicas y de entretenimiento.Se puede pasear caminando o recorrerla en los buses que pasan continuamente.
#    ... y 18 más
#
# 🏷️ Subjetiva:
#    1. Noche diferente. Speechless. I never thought I'd have such a pleasant time. For several hours, it envelops you in its charm. Spectacular tour thanks to Cezar, our guide. I say thank you, Cezar, on behalf of everyone who was there. Highly recommended.
#    2. Increíble. Ninguno, me encantó toda la experiencias fue increíble cada unos de las paradas así como su comida  . 10 de 10 . Me gustó y volvería a venir.
#    3. Genial. ¡Lo mejor que he pasado en mucho tiempo! Definitivamente volviendo. Voy a contar a amigos y familiares sobre mi experiencia aquí. No puedo esperar a volver.
#    ... y 627 más
#
# 🏷️ Mixta:
#    1. Fun and exciting. Transportation was organized.  Reception at the park was great with greetings by professionals.  The shops were presented well and employees were friendly.  The boat ride was excellent and the captain and guide made it a lot of fun.  The tour was an exciting experience!  Thank you.
#    2. Great fun in Cancun. This is a fabulous show, high energy and great way to have fun in a safe environment.  Our tour guide Ricardo Romero and his team were very engaging, fun to be with and made the whole evening memorable!  I would definitely go back!.
#    3. Xochimilco excelente experiencia. Joss y Roberto dieron muy buen servicio y ambiente, mucho baile, comida y bebida precisa y la experiencia excelente. Sin duda regresamos.
#    ... y 1810 más

# %%
# Mostrar ejemplos con desglose detallado
mostrar_ejemplos_detallados(df_clasificado)
# Out:
# 🔍 EJEMPLOS DE OPINIONES CON DESGLOSE DETALLADO
# ============================================================
#
# 🎯 EJEMPLOS DE OPINIONES OBJETIVAS
# ----------------------------------------
#
# 📌 Ejemplo 1:
# 🏛️ Avenida Kukulkan - Cancun
# ⭐ Calificación: 5/5
# 💬 "Great location. Convenient location. Main road, easy access to local bus routes, tourist places, shopping centers, restaurants, activities and hotels."
# 🤖 Clasificaciones:
#    • HuggingFace: Objetivo
#    • Por frases: Mixta
#    • LLM (GPT): Objetiva
#
# 📊 Desglose por frases:
#    • Total: 3
#    • Subjetivas: 2 (66.7%)
#    • Objetivas: 1 (33.3%)
#
# 📌 Ejemplo 2:
# 🏛️ Vallarta Bahia De Banderas - Puerto_vallarta
# ⭐ Calificación: 5/5
# 💬 "bahia de banderas. bahia de banderas esta ubicado en el estado de nayarit pasando el rio ameca hay transporte para ir a la playa disfrutar con amigos y familiares."
# 🤖 Clasificaciones:
#    • HuggingFace: Objetivo
#    • Por frases: Objetivo
#    • LLM (GPT): Objetiva
#
# 📊 Desglose por frases:
#    • Total: 3
#    • Subjetivas: 0 (0.0%)
#    • Objetivas: 3 (100.0%)
#
# 🎯 EJEMPLOS DE OPINIONES SUBJETIVAS
# ----------------------------------------
#
# 📌 Ejemplo 1:
# 🏛️ Isla De Los Venados - Mazatlan
# ⭐ Calificación: 5/5
# 💬 "Preciosa vista del malecón. Es una isla pequeña y muy tranquila, con una inigualable vista hacia el malecón , zona dorada y sus alrededores."
# 🤖 Clasificaciones:
#    • HuggingFace: Subjetivo
#    • Por frases: Subjetivo
#    • LLM (GPT): Subjetiva
#
# 📊 Desglose por frases:
#    • Total: 2
#    • Subjetivas: 2 (100.0%)
#    • Objetivas: 0 (0.0%)
#
# 📌 Ejemplo 2:
# 🏛️ Museo Internacional Del Barroco - Puebla
# ⭐ Calificación: 5/5
# 💬 "Bonito museo. Muy bonito museo y muy interesante, gracias al guía por ser tan amable y atento. Nos encantó la explicación. Recomiendo lo visiten."
# 🤖 Clasificaciones:
#    • HuggingFace: Subjetivo
#    • Por frases: Subjetivo
#    • LLM (GPT): Subjetiva
#
# 📊 Desglose por frases:
#    • Total: 4
#    • Subjetivas: 4 (100.0%)
#    • Objetivas: 0 (0.0%)
#
# 🎯 EJEMPLOS DE OPINIONES MIXTAS
# ----------------------------------------
#
# 📌 Ejemplo 1:
# 🏛️ Fuertes De Loreto - Puebla
# ⭐ Calificación: 5/5
# 💬 "Muy bien cuidado!. La zona de Los Fuertes es bastante extensa y se encuentra en zona de ladera por lo que es recomendable usar calzado cómodo para caminar. Además de que es necesario llegar temprano (por la mañana) si se desea poder ver todo, lod dos fuertes, el museo, tomar el teleférico, caminar por el parque y los alrededores de los fuertes, entrar al planetario y disfrutar de una de sus funciones. Te recomiendo llevar gorra/sombrero y lentes para sol además de agua por si deseas caminar los parques pues puestos con agua encuentras sólo fuera de un fuerte y en la zona del planetario. Vale la pena la caminata!."
# 🤖 Clasificaciones:
#    • HuggingFace: Subjetivo
#    • Por frases: Mixta
#    • LLM (GPT): Mixta
#
# 📊 Desglose por frases:
#    • Total: 5
#    • Subjetivas: 2 (40.0%)
#    • Objetivas: 3 (60.0%)
#
# 📌 Ejemplo 2:
# 🏛️ Acuario Mazatlan - Mazatlan
# ⭐ Calificación: 3/5
# 💬 "Fun. The aquarium is a few dollars via Uber from the cruise ship. It would probably be doable in half a day—maybe 3 hours max. There is a cute sea lion show and some nice aquariums that are well kept. Everything seems to be in good working order and well taken care of. We were lucky enough to SCUBA in the aquarium. The staff was helpful and kind. We brought our own gear, and they allowed us to use it. Our cousin rented gear, and it had no SPG!Overall, a fun time. Do not eat here—the food is awful, slow, and expensive. Except the cotton candy machine by the food court, which is just fun! Lots of places to eat just outside."
# 🤖 Clasificaciones:
#    • HuggingFace: Subjetivo
#    • Por frases: Mixta
#    • LLM (GPT): Mixta
#
# 📊 Desglose por frases:
#    • Total: 12
#    • Subjetivas: 6 (50.0%)
#    • Objetivas: 6 (50.0%)

# %%
# Análisis avanzado de frases usando subjetividad
analisis_avanzado_frases(df_clasificado)
# Out:
# 🔬 ANÁLISIS AVANZADO DE FRASES
# ==================================================
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# Device set to use cuda:0
# Device set to use cuda:0
# 🎯 OPINIÓN 1:
# 💬 "Fun and exciting. Transportation was organized.  Reception at the park was great with greetings by professionals.  The shops were presented well and employees were friendly.  The boat ride was excellent and the captain and guide made it a lot of fun.  The tour was an exciting experience!  Thank you."
# 🏛️ Xoximilco Cancun By Xcaret - Cancun
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 📊 DESGLOSE:
#    • Total: 7 frases
#    • Subjetivas: 5 (71.4%)
#    • Objetivas: 2 (28.6%)
#    • Clasificación: Mixta
#
# 📝 FRASES:
#    💭 1. [Subjetivo] "Fun and exciting."
#    📊 2. [Objetivo] "Transportation was organized."
#    💭 3. [Subjetivo] "Reception at the park was great with greetings by professionals."
#    📊 4. [Objetivo] "The shops were presented well and employees were friendly."
#    💭 5. [Subjetivo] "The boat ride was excellent and the captain and guide made it a lot of fun."
#    💭 6. [Subjetivo] "The tour was an exciting experience!"
#    💭 7. [Subjetivo] "Thank you."
#
# 🎯 OPINIÓN 2:
# 💬 "Increíble. Ninguno, me encantó toda la experiencias fue increíble cada unos de las paradas así como su comida  . 10 de 10 . Me gustó y volvería a venir."
# 🏛️ Xoximilco Cancun By Xcaret - Cancun
#
# 📊 DESGLOSE:
#    • Total: 5 frases
#    • Subjetivas: 4 (80.0%)
#    • Objetivas: 1 (20.0%)
#    • Clasificación: Mixta
#
# 📝 FRASES:
#    💭 1. [Subjetivo] "Increíble."
#    💭 2. [Subjetivo] "Ninguno, me encantó toda la experiencias"
#    💭 3. [Subjetivo] "fue increíble cada unos de las paradas así como su comida  ."
#    📊 4. [Objetivo] "10 de 10 ."
#    💭 5. [Subjetivo] "Me gustó y volvería a venir."
