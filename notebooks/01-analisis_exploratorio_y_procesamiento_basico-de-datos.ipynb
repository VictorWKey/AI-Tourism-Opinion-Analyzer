# %% [markdown]
# # Análisis Exploratorio y Procesamiento Básico de los Datos
#
# Este notebook realiza un análisis exploratorio y procesamiento básico de los datos de opiniones turísticas usando módulos especializados con una estructura modular mejorada.
#
# ## Objetivo
# - Cargar y procesar datos usando los módulos de procesamiento modular

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path

sys.path.append('../scripts')

from exploracion import (
    AnalizadorGeneral, 
    AnalizadorCategorico,
    AnalizadorTemporal,
    AnalizadorTexto,

    analisis_final_completo
)

from procesamiento import (
    procesar_dataset_completo
)

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')
sns.set_palette("husl")
# %matplotlib inline

print("✅ Librerías y módulos importados correctamente")
# Out:
# ✅ Librerías y módulos importados correctamente

# %% [markdown]
# ## 1. Procesamiento Completo de Datos
#
# Usando el pipeline completo de procesamiento que incluye: carga, limpieza de fechas, eliminación de duplicados y creación de texto consolidado.

# %%
print("🚀 Iniciando procesamiento completo del dataset...")
print("="*60)

df_opiniones = procesar_dataset_completo('../data')

print(f"\n🎉 ¡Procesamiento exitoso!")
print(f"📊 Dataset final: {len(df_opiniones):,} filas × {len(df_opiniones.columns)} columnas")
print(f"📁 Guardado como: dataset_opiniones_consolidado.csv")

df_analisis = df_opiniones.copy() if df_opiniones is not None else None
# Out:
# 🚀 Iniciando procesamiento completo del dataset...
# ============================================================
# ================================================================================
#              PIPELINE DE PROCESAMIENTO COMPLETO
# ================================================================================
# ✅ Directorios verificados: ../data/raw, ../data/processed
#
# 🔄 PASO 1: Cargando datos...
# Ciudades encontradas en raw: ['mazatlan', 'cancun', 'puebla', 'puerto_vallarta', 'cdmx']
#
# Procesando ciudad: mazatlan
# Archivos encontrados: 10
# ✓ mazatlan-malecon-de-mazatlan.csv: 50 filas cargadas
# ✓ mazatlan-playa-cerritos.csv: 50 filas cargadas
# ✓ mazatlan-playa-brujas.csv: 50 filas cargadas
# ✓ mazatlan-acuario-mazatlan.csv: 50 filas cargadas
# ✓ mazatlan-viejo-mazatlan.csv: 50 filas cargadas
# ✓ mazatlan-isla-de-los-venados.csv: 50 filas cargadas
# ✓ mazatlan-el-faro-de-mazatlan.csv: 50 filas cargadas
# ✓ mazatlan-plaza-machado.csv: 50 filas cargadas
# ✓ mazatlan-isla-de-la-piedras.csv: 50 filas cargadas
# ✓ mazatlan-catedral-mazatlan-basilica-de-la-inmaculada-concepcion.csv: 50 filas cargadas
#
# Procesando ciudad: cancun
# Archivos encontrados: 10
# ✓ cancun-ultramar-cancun.csv: 50 filas cargadas
# ✓ cancun-museo-maya-de-cancun-y-zona-arqueologica-de-san-miguelito.csv: 50 filas cargadas
# ✓ cancun-acuario-interactivo.csv: 50 filas cargadas
# ✓ cancun-la-isla.csv: 50 filas cargadas
# ✓ cancun-playa-delfines.csv: 50 filas cargadas
# ✓ cancun-ventura-park.csv: 50 filas cargadas
# ✓ cancun-xoximilco-cancun-by-xcaret.csv: 50 filas cargadas
# ✓ cancun-avenida-kukulkan.csv: 50 filas cargadas
# ✓ cancun-playa-tortugas.csv: 50 filas cargadas
# ✓ cancun-puerto-maya-cancun.csv: 50 filas cargadas
#
# Procesando ciudad: puebla
# Archivos encontrados: 10
# ✓ puebla-acuario-michin-puebla.csv: 50 filas cargadas
# ✓ puebla-catedral-de-puebla.csv: 50 filas cargadas
# ✓ puebla-zocalo-de-puebla.csv: 50 filas cargadas
# ✓ puebla-callejon-de-los-sapos.csv: 50 filas cargadas
# ✓ puebla-zoo-parque-loro-puebla.csv: 50 filas cargadas
# ✓ puebla-museo-internacional-del-barroco.csv: 50 filas cargadas
# ✓ puebla-fuertes-de-loreto.csv: 50 filas cargadas
# ✓ puebla-capilla-del-rosario.csv: 50 filas cargadas
# ✓ puebla-mercado-el-parian.csv: 50 filas cargadas
# ✓ puebla-africam-safari.csv: 50 filas cargadas
#
# Procesando ciudad: puerto_vallarta
# Archivos encontrados: 10
# ✓ puerto-vallarta-edenva-parque-ecoturistico.csv: 50 filas cargadas
# ✓ puerto-vallarta-zona-romantica.csv: 50 filas cargadas
# ✓ puerto-vallarta-malecon-boardwalk.csv: 50 filas cargadas
# ✓ puerto-vallarta-parroquia-de-nuestra-señora-de-guadalupe.csv: 50 filas cargadas
# ✓ puerto-vallarta-playa-de-los-muertos.csv: 50 filas cargadas
# ✓ puerto-vallarta-san-pancho.csv: 43 filas cargadas
# ✓ puerto-vallarta-bahia-de-banderas.csv: 50 filas cargadas
# ✓ puerto-vallarta-marina-vallarta.csv: 50 filas cargadas
# ✓ puerto-mirador-de-la-cruz.csv: 50 filas cargadas
# ✓ puerto-vallarta-playa-de-las-gemelas.csv: 50 filas cargadas
#
# Procesando ciudad: cdmx
# Archivos encontrados: 10
# ✓ cdmx-palacio-de-bellas-artes.csv: 50 filas cargadas
# ✓ cdmx-basilica-de-la-virgen-guadalupe.csv: 50 filas cargadas
# ✓ cdmx-museo-nacional-de-antropologia.csv: 50 filas cargadas
# ✓ cdmx-acuario-michin-ciudad-de-mexico.csv: 50 filas cargadas
# ✓ cdmx-coyoacan.csv: 50 filas cargadas
# ✓ cdmx-museo-soumaya.csv: 50 filas cargadas
# ✓ cdmx-museo-del-templo-mayor.csv: 50 filas cargadas
# ✓ cdmx-zocalo-de-la-ciudad-de-mexico.csv: 50 filas cargadas
# ✓ cdmx-castillo-de-chapultepec.csv: 50 filas cargadas
# ✓ cdmx-museo-frida-kahlo.csv: 50 filas cargadas
#
# === RESUMEN ===
# Total de filas: 2493
# Ciudades procesadas: 5
# Atracciones procesadas: 50
#
# 🔄 PASO 2: Convirtiendo fechas...
# === CONVERSIÓN DE TIPOS DE DATOS PARA FECHAS ===
# Ejemplos de fechas ANTES de conversión:
# FechaEstadia: ['ago de 2025', 'ene de 2025', 'ene de 2025']
#
# Convirtiendo fechas...
#
# Ejemplos de fechas DESPUÉS de conversión:
# FechaEstadia: [Timestamp('2025-08-01 00:00:00'), Timestamp('2025-01-01 00:00:00'), Timestamp('2025-01-01 00:00:00')]
# Tipo: datetime64[ns]
# FechaEstadia nulas: 19
# ✅ Conversión de fechas completada
#
# 🔄 PASO 3: Limpieza específica de columnas inecesarias para el analisis
# === ELIMINACIÓN DE COLUMNA FechaOpinion ===
# ✅ Columna FechaOpinion eliminada exitosamente
# 📊 Columnas restantes: 8
# === ELIMINACIÓN DE COLUMNA TipoViaje ===
# ✅ Columna TipoViaje eliminada exitosamente
# 📊 Columnas restantes: 7
# === ELIMINACIÓN DE COLUMNA OrigenAutor ===
# ✅ Columna OrigenAutor eliminada exitosamente
# 📊 Columnas restantes: 6
# === ELIMINACIÓN DE FILAS CON FechaEstadia NULA ===
# 📊 Análisis de FechaEstadia:
#    • Total de filas: 2,493
#    • Filas con FechaEstadia nula: 19
#    • Porcentaje de nulos: 0.76%
#
# 🗑️ Eliminando 19 filas con FechaEstadia nula...
# ✅ Filas con FechaEstadia nula eliminadas exitosamente
#    • Filas antes: 2,493
#    • Filas después: 2,474
#    • Filas eliminadas: 19
#    • Verificación: FechaEstadia nulas restantes = 0
#
# 🔄 PASO 4: Eliminando duplicados...
# === ELIMINACIÓN DE DUPLICADOS ===
# Filas completamente duplicadas encontradas: 10
# Duplicados por título + review + ciudad + atracción: 10
# Porcentaje de duplicados completos: 0.40%
#
# 🔄 Eliminando 10 filas duplicadas...
# ✅ Duplicados eliminados exitosamente
#    Filas antes: 2,474
#    Filas después: 2,464
#    Filas eliminadas: 10
#
# 🔄 PASO 5: Creando texto consolidado...
# === CREACIÓN DE COLUMNA DE TEXTO CONSOLIDADO ===
# Combinando todos los campos en una narrativa coherente...
# Generando texto consolidado para cada registro...
# ✅ Columna 'TituloReview' creada exitosamente
# Total de registros procesados: 2464
#
# 📊 ESTADÍSTICAS DE TEXTO CONSOLIDADO:
#    • Longitud promedio: 334.8 caracteres
#    • Longitud mínima: 106 caracteres
#    • Longitud máxima: 5005 caracteres
#    • Mediana: 238.0 caracteres
#
# 📝 EJEMPLOS DE TEXTO CONSOLIDADO:
# ================================================================================
# • mazatlan - playa brujas:
#   'Fantástica playa!. Nos alojamos en el Riu Emerald Bay, así que pasamos un tiempo en Playa Brujas. Re...'
#
# • cdmx - museo soumaya:
#   'Agradablemente sorprendido. Gratamente sorprendido por nuestra visita. A medida que el museo va el m...'
#
# • cancun - playa delfines:
#   'Arena blanca, mar turquesa, opciones de comida y bebida a la orilla de la playa. Es una playa muy bo...'
#
# • mazatlan - playa cerritos:
#   'Excelente opción para disfrutar sin tanta saturación de personas. Lugar tranquilo, seguro, la playa ...'
#
# • cancun - avenida kukulkan:
#   'Hermosa Avenida. Una avenida que permite disfrutar de la naturaleza unida al avance de la ciudad. Ho...'
#
#
# 🔄 PASO 6: Aplicando capitalización a columnas categóricas...
# ✅ Capitalización aplicada a ciudades y atracciones
#
# 🔄 PASO 7: Guardando dataset procesado...
# === GUARDANDO DATASET PROCESADO ===
# Columnas en el dataset final:
#  1. Titulo
#  2. Review
#  3. Calificacion
#  4. FechaEstadia
#  5. Ciudad
#  6. Atraccion
#  7. TituloReview
#
# Dimensiones finales: (2464, 7)
# Filas: 2,464
# Columnas: 7
#
# ✅ Dataset final guardado como '../data/processed/dataset_opiniones_consolidado.csv'
#
# 🔄 PASO 8: Exportando datasets por ciudad...
# 📁 Directorio creado/verificado: ../data/processed/datasets_por_ciudad/base
# 💾 dataset_mazatlan.csv: 500 filas guardadas
# 📁 Ubicación: ../data/processed/datasets_por_ciudad/base/dataset_mazatlan.csv
# 💾 dataset_cancun.csv: 483 filas guardadas
# 📁 Ubicación: ../data/processed/datasets_por_ciudad/base/dataset_cancun.csv
# 💾 dataset_puebla.csv: 500 filas guardadas
# 📁 Ubicación: ../data/processed/datasets_por_ciudad/base/dataset_puebla.csv
# 💾 dataset_puerto_vallarta.csv: 491 filas guardadas
# 📁 Ubicación: ../data/processed/datasets_por_ciudad/base/dataset_puerto_vallarta.csv
# 💾 dataset_cdmx.csv: 490 filas guardadas
# 📁 Ubicación: ../data/processed/datasets_por_ciudad/base/dataset_cdmx.csv
# ✅ Exportación por ciudades completada en: ../data/processed/datasets_por_ciudad
# � 5 datasets de ciudades creados
#
# ✅ PIPELINE DE PROCESAMIENTO COMPLETADO EXITOSAMENTE
#
# 🎉 ¡Procesamiento exitoso!
# 📊 Dataset final: 2,464 filas × 7 columnas
# 📁 Guardado como: dataset_opiniones_consolidado.csv

# %%
df_opiniones.head()
# Out:
#                      Titulo  \
# 0      ¡Divertido y seguro!
# 1        Un mes en Mazatlán
# 2               Maravilloso
# 3  Caminando por el Malecón
# 4  Nunca más, por desgracia
#
#                                               Review  Calificacion  \
# 0  Estoy muy impresionado con Mazatlán, Mx. . La ...             5
# 1  Acabamos de pasar un mes en Mazatlán. No estoy...             3
# 2  Ubicado en la zona más turística de Mazatlán, ...             5
# 3  Hermoso El Malecón de Mazatlán he caminado en ...             5
# 4  Mazatlán no es seguro. Lamento escribir esto, ...             1
#
#   FechaEstadia    Ciudad            Atraccion  \
# 0   2025-08-01  Mazatlan  Malecon De Mazatlan
# 1   2025-01-01  Mazatlan  Malecon De Mazatlan
# 2   2025-01-01  Mazatlan  Malecon De Mazatlan
# 3   2024-12-01  Mazatlan  Malecon De Mazatlan
# 4   2024-12-01  Mazatlan  Malecon De Mazatlan
#
#                                         TituloReview
# 0  ¡Divertido y seguro!. Estoy muy impresionado c...
# 1  Un mes en Mazatlán. Acabamos de pasar un mes e...
# 2  Maravilloso. Ubicado en la zona más turística ...
# 3  Caminando por el Malecón. Hermoso El Malecón d...
# 4  Nunca más, por desgracia. Mazatlán no es segur...

# %% [markdown]
# ## 2. Análisis Exploratorio Basico
#
# Ahora usaremos las funciones del módulo de exploración para realizar análisis descriptivos sin modificar los datos.

# %%
analizador_general = AnalizadorGeneral(df_analisis)

analizador_general.analizar_valores_nulos()
# Out:
# === ANÁLISIS DE VALORES NULOS ===
#               Valores_Nulos  Porcentaje
# Titulo                    0         0.0
# Review                    0         0.0
# Calificacion              0         0.0
# FechaEstadia              0         0.0
# Ciudad                    0         0.0
# Atraccion                 0         0.0
# TituloReview              0         0.0
#               Valores_Nulos  Porcentaje
# Titulo                    0         0.0
# Review                    0         0.0
# Calificacion              0         0.0
# FechaEstadia              0         0.0
# Ciudad                    0         0.0
# Atraccion                 0         0.0
# TituloReview              0         0.0

# %%
analizador_general.analizar_duplicados()
# Out:
# === ANÁLISIS DE DUPLICADOS ===
# Filas completamente duplicadas encontradas: 0
# Duplicados por título + review + ciudad + atracción: 0
# 0

# %% [markdown]
# ## 3. Análisis Descriptivo por Categorías

# %%
analizador_categorico = AnalizadorCategorico(df_analisis)

analizador_categorico.analizar_distribuciones_categoricas()
# Out:
# === DISTRIBUCIÓN POR CIUDADES ===
# Ciudad
# Mazatlan           500
# Puebla             500
# Puerto_vallarta    491
# Cdmx               490
# Cancun             483
# Name: count, dtype: int64
#
# Porcentaje por ciudad:
# Ciudad
# Mazatlan           20.29
# Puebla             20.29
# Puerto_vallarta    19.93
# Cdmx               19.89
# Cancun             19.60
# Name: count, dtype: float64

# %%
analizador_categorico = AnalizadorCategorico(df_analisis)
analizador_categorico.analizar_calificaciones()
# Out:
# === ANÁLISIS DE CALIFICACIONES ===
# Estadísticas descriptivas de calificaciones:
# count    2464.000000
# mean        4.428977
# std         1.014625
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: Calificacion, dtype: float64
#
# Distribución de calificaciones:
# Calificacion
# 1     101
# 2      60
# 3     180
# 4     463
# 5    1660
# Name: count, dtype: int64
#
# Calificación promedio general: 4.43

# %% [markdown]
# ## 4. Análisis de Longitud de Textos y Temporal

# %%
analizador_texto = AnalizadorTexto(df_analisis)

analizador_temporal = AnalizadorTemporal(df_analisis)

analizador_texto.analizar_longitud_textos()
print("\n")
analizador_temporal.analizar_temporal()
# Out:
# === ANÁLISIS DE LONGITUD DE TÍTULOS ===
# count    2464.000000
# mean       28.555601
# std        30.737520
# min         1.000000
# 25%        14.000000
# 50%        22.000000
# 75%        35.000000
# max      1008.000000
# Name: Titulo, dtype: float64
#
# === ANÁLISIS DE LONGITUD DE REVIEWS ===
# count    2464.000000
# mean      304.135552
# std       289.893020
# min        98.000000
# 25%       143.000000
# 50%       204.000000
# 75%       348.250000
# max      4962.000000
# Name: Review, dtype: float64
#
# === NÚMERO DE PALABRAS EN REVIEWS ===
# count    2464.000000
# mean       52.486201
# std        50.237065
# min         9.000000
# 25%        25.000000
# 50%        35.000000
# 75%        60.000000
# max       816.000000
# Name: Review, dtype: float64
#
#
# === ANÁLISIS TEMPORAL DE OPINIONES ===
# Ejemplos de fechas en el dataset:
# [Timestamp('2025-08-01 00:00:00'), Timestamp('2025-01-01 00:00:00'), Timestamp('2025-01-01 00:00:00'), Timestamp('2024-12-01 00:00:00'), Timestamp('2024-12-01 00:00:00'), Timestamp('2024-12-01 00:00:00'), Timestamp('2024-09-01 00:00:00'), Timestamp('2024-08-01 00:00:00'), Timestamp('2024-04-01 00:00:00'), Timestamp('2024-05-01 00:00:00')]
#
# Fechas únicas de opinión: 114
#
# Top 10 fechas con más opiniones:
# FechaEstadia
# 2025-08-01    149
# 2025-07-01     89
# 2025-01-01     73
# 2024-12-01     68
# 2024-06-01     65
# 2024-09-01     64
# 2024-05-01     63
# 2025-06-01     62
# 2024-10-01     62
# 2025-05-01     60
# Name: count, dtype: int64
# • Rango de fechas: 01/02/2015 - 01/09/2025
# • Período cubierto: 3865 días
# • Distribución por año:
#      2015: 4 opiniones (0.2%)
#      2016: 9 opiniones (0.4%)
#      2017: 34 opiniones (1.4%)
#      2018: 79 opiniones (3.2%)
#      2019: 195 opiniones (7.9%)
#      2020: 142 opiniones (5.8%)
#      2021: 119 opiniones (4.8%)
#      2022: 266 opiniones (10.8%)
#      2023: 348 opiniones (14.1%)
#      2024: 676 opiniones (27.4%)
#      2025: 592 opiniones (24.0%)

# %% [markdown]
# ## 5. Análisis Descriptivo final

# %%
analisis_final_completo(df_analisis)
# Out:
# ================================================================================
#                      ANÁLISIS FINAL COMPLETO
#                     DATASET COMPLETAMENTE LIMPIO
# ================================================================================
#
# 📊 RESUMEN GENERAL:
#    • Total de registros finales: 2,464
#    • Total de columnas: 7
#    • Ciudades: 5
#    • Atracciones: 50
#
# 🔍 CALIDAD DE DATOS FINAL:
#    • Valores nulos totales: 0
#    • Duplicados restantes: 0
#    • Integridad de datos: ✅ PERFECTA
#
# 🏙️ DISTRIBUCIÓN FINAL POR CIUDADES:
#    • MAZATLAN: 500 (20.3%)
#    • PUEBLA: 500 (20.3%)
#    • PUERTO_VALLARTA: 491 (19.9%)
#    • CDMX: 490 (19.9%)
#    • CANCUN: 483 (19.6%)
#
# ⭐ ANÁLISIS DE CALIFICACIONES FINAL:
#    • Promedio general: 4.43/5
#    • Mediana: 5.0/5
#    • Moda: 5/5
#    • Desviación estándar: 1.01
#
#    Distribución de calificaciones:
#      1 estrellas: 101 (4.1%)
#      2 estrellas: 60 (2.4%)
#      3 estrellas: 180 (7.3%)
#      4 estrellas: 463 (18.8%)
#      5 estrellas: 1,660 (67.4%)
#
# 🏆 TOP 5 ATRACCIONES POR CALIFICACIÓN PROMEDIO:
#    • Vallarta Edenva Parque Ecoturistico (Puerto_vallarta): 4.98/5 (48 opiniones)
#    • Puerto Maya Cancun (Cancun): 4.93/5 (45 opiniones)
#    • Xoximilco Cancun By Xcaret (Cancun): 4.93/5 (44 opiniones)
#    • Zoo Parque Loro Puebla (Puebla): 4.92/5 (50 opiniones)
#    • Capilla Del Rosario (Puebla): 4.84/5 (50 opiniones)
#
# ================================================================================
# ✅ ANÁLISIS FINAL COMPLETADO
# 🎯 Dataset completamente limpio y listo para análisis avanzados
# 📊 Calidad de datos: EXCELENTE
# ================================================================================

# %%
df_analisis.head()
# Out:
#                      Titulo  \
# 0      ¡Divertido y seguro!
# 1        Un mes en Mazatlán
# 2               Maravilloso
# 3  Caminando por el Malecón
# 4  Nunca más, por desgracia
#
#                                               Review  Calificacion  \
# 0  Estoy muy impresionado con Mazatlán, Mx. . La ...             5
# 1  Acabamos de pasar un mes en Mazatlán. No estoy...             3
# 2  Ubicado en la zona más turística de Mazatlán, ...             5
# 3  Hermoso El Malecón de Mazatlán he caminado en ...             5
# 4  Mazatlán no es seguro. Lamento escribir esto, ...             1
#
#   FechaEstadia    Ciudad            Atraccion  \
# 0   2025-08-01  Mazatlan  Malecon De Mazatlan
# 1   2025-01-01  Mazatlan  Malecon De Mazatlan
# 2   2025-01-01  Mazatlan  Malecon De Mazatlan
# 3   2024-12-01  Mazatlan  Malecon De Mazatlan
# 4   2024-12-01  Mazatlan  Malecon De Mazatlan
#
#                                         TituloReview
# 0  ¡Divertido y seguro!. Estoy muy impresionado c...
# 1  Un mes en Mazatlán. Acabamos de pasar un mes e...
# 2  Maravilloso. Ubicado en la zona más turística ...
# 3  Caminando por el Malecón. Hermoso El Malecón d...
# 4  Nunca más, por desgracia. Mazatlán no es segur...
